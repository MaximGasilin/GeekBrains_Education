# %% [markdown]
# Не очень понимаю, что нужно сдавать в качестве выполненного домашнего задания, но в рамках курсового проекта будет реализовано:

# %% [markdown]
# 1. Болталка с медицинской базой;
# 2. Связь с модной нынче нейросетью ChatGPT.
