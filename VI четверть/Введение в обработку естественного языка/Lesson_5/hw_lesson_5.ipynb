# %% [markdown]
# ### Задание 1.
# Написать теггер на данных с русским языком
# проверить UnigramTagger, BigramTagger, TrigramTagger и их комбинации
# написать свой теггер как на занятии, попробовать разные векторайзеры, добавить знание не только букв но и слов
# сравнить все реализованные методы, сделать выводы

# %%
# !pip install pyconll
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyconll
#   Downloading pyconll-3.1.0-py3-none-any.whl (26 kB)
# Installing collected packages: pyconll
# Successfully installed pyconll-3.1.0

# %%
# !pip install -U spacy
# !python -m spacy info
# !python -m spacy download ru_core_news_sm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.4)
# Collecting spacy
#   Downloading spacy-3.5.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 49.0 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (21.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.5)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.0.1)
# Installing collected packages: spacy
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.4
#     Uninstalling spacy-3.4.4:
#       Successfully uninstalled spacy-3.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-sm 3.4.1 requires spacy<3.5.0,>=3.4.0, but you have spacy 3.5.0 which is incompatible.
# Successfully installed spacy-3.5.0
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-01-25 17:44:02.784808: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# /usr/local/lib/python3.8/dist-packages/spacy/util.py:877: UserWarning: [W095] Model 'en_core_web_sm' (3.4.1) was trained with spaCy v3.4 and may not be 100% compatible with the current version (3.5.0). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
#
# ============================== Info about spaCy ==============================
#
# spaCy version    3.5.0
# Location         /usr/local/lib/python3.8/dist-packages/spacy
# Platform         Linux-5.10.147+-x86_64-with-glibc2.29
# Python version   3.8.10
# Pipelines        en_core_web_sm (3.4.1)
#
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-01-25 17:44:11.302878: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ru-core-news-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.5.0/ru_core_news_sm-3.5.0-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 22.8 MB/s eta 0:00:00
# Collecting pymorphy3>=1.0.0
#   Downloading pymorphy3-1.2.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 KB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.8/dist-packages (from ru-core-news-sm==3.5.0) (3.5.0)
# Collecting pymorphy3-dicts-ru
#   Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 16.6 MB/s eta 0:00:00
# Collecting docopt>=0.6
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.21.6)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (8.1.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.3.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.4.5)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.10.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (4.64.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.0.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (21.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.10.4)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.7.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (6.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.0.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (57.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.25.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.11)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (4.0.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.1)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=9acc458f2185f50b463cb4b94741c87d7e06e5f35c259d3ed6db23e6bd9ec134
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built docopt
# Installing collected packages: pymorphy3-dicts-ru, docopt, dawg-python, pymorphy3, ru-core-news-sm
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy3-1.2.0 pymorphy3-dicts-ru-2.4.417150.4580142 ru-core-news-sm-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')

# %%
import pyconll

import pandas as pd

import nltk
from nltk.tag import UnigramTagger, BigramTagger, TrigramTagger

from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer, HashingVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, accuracy_score, classification_report

# %%
full_train = pyconll.load_from_file('ru_syntagrus-ud-train-a.conllu')
full_test = pyconll.load_from_file('ru_syntagrus-ud-dev.conllu')

# %%
for sent in full_train[:2]:
    for token in sent:
        print(token.form, token.upos)
    print()
# Out:
# Анкета NOUN
# . PUNCT
#
# Начальник NOUN
# областного ADJ
# управления NOUN
# связи NOUN
# Семен PROPN
# Еремеевич PROPN
# был AUX
# человек NOUN
# простой ADJ
# , PUNCT
# приходил VERB
# на ADP
# работу NOUN
# всегда ADV
# вовремя ADV
# , PUNCT
# здоровался VERB
# с ADP
# секретаршей NOUN
# за ADP
# руку NOUN
# и CCONJ
# иногда ADV
# даже PART
# писал VERB
# в ADP
# стенгазету NOUN
# заметки NOUN
# под ADP
# псевдонимом NOUN
# " PUNCT
# Муха NOUN
# " PUNCT
# . PUNCT

# %%
fdata_train = []
for sent in full_train[:]:
    fdata_train.append([(token.form, token.upos) for token in sent])
    
fdata_test = []
for sent in full_test[:]:
    fdata_test.append([(token.form, token.upos) for token in sent])
    
fdata_sent_test = []
for sent in full_test[:]:
    fdata_sent_test.append([token.form for token in sent])

# %%
MAX_SENT_LEN = max(len(sent) for sent in full_train)
MAX_ORIG_TOKEN_LEN = max(len(token.form) for sent in full_train for token in sent)
print('Наибольшая длина предложения', MAX_SENT_LEN)
print('Наибольшая длина токена', MAX_ORIG_TOKEN_LEN)
# Out:
# Наибольшая длина предложения 194
# Наибольшая длина токена 31

# %%
fdata_train[:3]
# Out:
# [[('Анкета', 'NOUN'), ('.', 'PUNCT')],
#  [('Начальник', 'NOUN'),
#   ('областного', 'ADJ'),
#   ('управления', 'NOUN'),
#   ('связи', 'NOUN'),
#   ('Семен', 'PROPN'),
#   ('Еремеевич', 'PROPN'),
#   ('был', 'AUX'),
#   ('человек', 'NOUN'),
#   ('простой', 'ADJ'),
#   (',', 'PUNCT'),
#   ('приходил', 'VERB'),
#   ('на', 'ADP'),
#   ('работу', 'NOUN'),
#   ('всегда', 'ADV'),
#   ('вовремя', 'ADV'),
#   (',', 'PUNCT'),
#   ('здоровался', 'VERB'),
#   ('с', 'ADP'),
#   ('секретаршей', 'NOUN'),
#   ('за', 'ADP'),
#   ('руку', 'NOUN'),
#   ('и', 'CCONJ'),
#   ('иногда', 'ADV'),
#   ('даже', 'PART'),
#   ('писал', 'VERB'),
#   ('в', 'ADP'),
#   ('стенгазету', 'NOUN'),
#   ('заметки', 'NOUN'),
#   ('под', 'ADP'),
#   ('псевдонимом', 'NOUN'),
#   ('"', 'PUNCT'),
#   ('Муха', 'NOUN'),
#   ('"', 'PUNCT'),
#   ('.', 'PUNCT')],
#  [('В', 'ADP'),
#   ('приемной', 'NOUN'),
#   ('его', 'PRON'),
#   ('с', 'ADP'),
#   ('утра', 'NOUN'),
#   ('ожидали', 'VERB'),
#   ('посетители', 'NOUN'),
#   (',', 'PUNCT'),
#   ('-', 'PUNCT'),
#   ('кое-кто', 'PRON'),
#   ('с', 'ADP'),
#   ('важными', 'ADJ'),
#   ('делами', 'NOUN'),
#   (',', 'PUNCT'),
#   ('а', 'CCONJ'),
#   ('кое-кто', 'PRON'),
#   ('и', 'PART'),
#   ('с', 'ADP'),
#   ('такими', 'DET'),
#   (',', 'PUNCT'),
#   ('которые', 'PRON'),
#   ('легко', 'ADV'),
#   ('можно', 'ADV'),
#   ('было', 'AUX'),
#   ('решить', 'VERB'),
#   ('в', 'ADP'),
#   ('нижестоящих', 'ADJ'),
#   ('инстанциях', 'NOUN'),
#   (',', 'PUNCT'),
#   ('не', 'PART'),
#   ('затрудняя', 'VERB'),
#   ('Семена', 'PROPN'),
#   ('Еремеевича', 'PROPN'),
#   ('.', 'PUNCT')]]

# %%
unigram_tagger = UnigramTagger(fdata_train)
acc_u = unigram_tagger.evaluate(fdata_test)
display(acc_u)
# Out:
# <ipython-input-12-c0c1d20b533d>:2: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   acc_u = unigram_tagger.evaluate(fdata_test)
# 0.823732013802982

# %%
bigram_tagger = BigramTagger(fdata_train)
acc_b = bigram_tagger.evaluate(fdata_test)
display(acc_b)
# Out:
# <ipython-input-14-8fa1fd4878f1>:2: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   acc_b = bigram_tagger.evaluate(fdata_test)
# 0.6093886320724006

# %%
trigram_tagger = TrigramTagger(fdata_train)
acc_t = trigram_tagger.evaluate(fdata_test)
display(acc_t)
# Out:
# <ipython-input-16-921b35dd23f0>:2: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   acc_t = trigram_tagger.evaluate(fdata_test)
# 0.1778631421316492

# %%
combination_1 = [BigramTagger, TrigramTagger]
combination_2 = [TrigramTagger, UnigramTagger]
combination_3 = [UnigramTagger, BigramTagger]
combination_4 = [BigramTagger, TrigramTagger, UnigramTagger]

# %%
def backoff_tagger(train_sents, tagger_classes, backoff=None):
    for cls in tagger_classes:
        backoff = cls(train_sents, backoff=backoff)
    return backoff

acc_bo = []

for combination in [combination_1, combination_2, combination_3, combination_4]:
    backoff = nltk.DefaultTagger('NN') 
    tag = backoff_tagger(fdata_train,  
                         combination,  
                         backoff = backoff) 

    acc_bo.append(tag.evaluate(fdata_test))

acc_bo
# Out:
# <ipython-input-22-a1b8d409cd35>:14: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   acc_bo.append(tag.evaluate(fdata_test))
# [0.1750309264926102,
#  0.21248779217396965,
#  0.8275343446838986,
#  0.3623152548994075]

# %%
result = pd.DataFrame({'Tagger': ['UnigramTagger', 'BigramTagger', 'TrigramTagger', 'BigramTagger & TrigramTagger', 'TrigramTagger & UnigramTagger', 'UnigramTagger & BigramTagger', 'All taggers'], 'Accuracy' : [acc_u, acc_b, acc_t] + acc_bo})
result.sort_values('Accuracy', ascending=False)
# Out:
#                           Tagger  Accuracy
# 5   UnigramTagger & BigramTagger  0.827534
# 0                  UnigramTagger  0.823732
# 1                   BigramTagger  0.609389
# 6                    All taggers  0.362315
# 4  TrigramTagger & UnigramTagger  0.212488
# 2                  TrigramTagger  0.177863
# 3   BigramTagger & TrigramTagger  0.175031

# %%
train_tok = []
train_label = []
for sent in fdata_train[:]:
    for tok in sent:
        train_tok.append(tok[0])
        train_label.append('NO_TAG' if tok[1] is None else tok[1])
        
test_tok = []
test_label = []
for sent in fdata_test[:]:
    for tok in sent:
        test_tok.append(tok[0])
        test_label.append('NO_TAG' if tok[1] is None else tok[1])

# %%
le = LabelEncoder()
train_enc_labels = le.fit_transform(train_label)
test_enc_labels = le.transform(test_label)
le.classes_
# Out:
# array(['ADJ', 'ADP', 'ADV', 'AUX', 'CCONJ', 'DET', 'INTJ', 'NOUN',
#        'NO_TAG', 'NUM', 'PART', 'PRON', 'PROPN', 'PUNCT', 'SCONJ', 'SYM',
#        'VERB', 'X'], dtype='<U6')

# %%
vectorizers = [CountVectorizer(ngram_range=(1, 3), analyzer='char'), 
               TfidfVectorizer(ngram_range=(1, 3), analyzer='char'), 
               HashingVectorizer(ngram_range=(1, 3), analyzer='char', n_features=1000)] 
vectorizers_word = [CountVectorizer(ngram_range=(1, 3), analyzer='word'), 
               TfidfVectorizer(ngram_range=(1, 3), analyzer='word'), 
               HashingVectorizer(ngram_range=(1, 3), analyzer='word', n_features=1000)] 
n_features = [2000, 3000, 5000, 10000]
hvectorizer = [HashingVectorizer(ngram_range=(1, 3), analyzer='char', n_features=feat) for feat in n_features]
hvectorizer_word = [HashingVectorizer(ngram_range=(1, 3), analyzer='word', n_features=feat) for feat in n_features]

# %%
f1_scores = []
acc_scores = []

for vectorizer in vectorizers + vectorizers_word + hvectorizer + hvectorizer_word:
    X_train = vectorizer.fit_transform(train_tok)
    X_test = vectorizer.transform(test_tok[:115000])
    
    lr = LogisticRegression(random_state=0, max_iter=100)
    lr.fit(X_train, train_enc_labels)
    pred = lr.predict(X_test)
    f1 = f1_score(test_enc_labels[:115000], pred, average='weighted')
    f1_scores.append(f1)
    acc = accuracy_score(test_enc_labels[:115000], pred)
    acc_scores.append(acc)
    
    print(vectorizer)
    print(classification_report(test_enc_labels[:115000], pred, target_names=le.classes_))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# CountVectorizer(analyzer='char', ngram_range=(1, 3))
#               precision    recall  f1-score   support
#
#          ADJ       0.92      0.91      0.92     11247
#          ADP       0.98      1.00      0.99     10255
#          ADV       0.92      0.90      0.91      5986
#          AUX       0.81      0.97      0.88      1058
#        CCONJ       0.88      0.98      0.93      4276
#          DET       0.88      0.75      0.81      2978
#         INTJ       0.33      0.36      0.35        11
#         NOUN       0.92      0.95      0.94     27241
#       NO_TAG       1.00      1.00      1.00       197
#          NUM       0.86      0.90      0.88      1436
#         PART       0.95      0.78      0.86      3762
#         PRON       0.83      0.89      0.86      5346
#        PROPN       0.79      0.59      0.67      4315
#        PUNCT       1.00      1.00      1.00     21941
#        SCONJ       0.81      0.91      0.86      2176
#          SYM       1.00      0.68      0.81        53
#         VERB       0.94      0.94      0.94     12617
#            X       0.47      0.16      0.24       105
#
#     accuracy                           0.93    115000
#    macro avg       0.85      0.82      0.82    115000
# weighted avg       0.93      0.93      0.93    115000
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# TfidfVectorizer(analyzer='char', ngram_range=(1, 3))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          ADJ       0.90      0.91      0.91     11247
#          ADP       0.99      0.99      0.99     10255
#          ADV       0.92      0.86      0.89      5986
#          AUX       0.81      0.97      0.89      1058
#        CCONJ       0.88      0.98      0.93      4276
#          DET       0.80      0.83      0.82      2978
#         INTJ       0.00      0.00      0.00        11
#         NOUN       0.90      0.96      0.93     27241
#       NO_TAG       1.00      1.00      1.00       197
#          NUM       0.85      0.90      0.87      1436
#         PART       0.95      0.79      0.86      3762
#         PRON       0.87      0.84      0.86      5346
#        PROPN       0.80      0.52      0.63      4315
#        PUNCT       1.00      1.00      1.00     21941
#        SCONJ       0.81      0.91      0.86      2176
#          SYM       1.00      0.64      0.78        53
#         VERB       0.93      0.93      0.93     12617
#            X       0.45      0.09      0.14       105
#
#     accuracy                           0.92    115000
#    macro avg       0.83      0.78      0.79    115000
# weighted avg       0.92      0.92      0.92    115000
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# HashingVectorizer(analyzer='char', n_features=1000, ngram_range=(1, 3))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          ADJ       0.84      0.84      0.84     11247
#          ADP       0.97      0.98      0.98     10255
#          ADV       0.83      0.79      0.81      5986
#          AUX       0.81      0.97      0.88      1058
#        CCONJ       0.88      0.97      0.93      4276
#          DET       0.80      0.80      0.80      2978
#         INTJ       0.00      0.00      0.00        11
#         NOUN       0.84      0.90      0.87     27241
#       NO_TAG       1.00      1.00      1.00       197
#          NUM       0.81      0.82      0.82      1436
#         PART       0.92      0.78      0.84      3762
#         PRON       0.84      0.86      0.85      5346
#        PROPN       0.72      0.45      0.55      4315
#        PUNCT       1.00      1.00      1.00     21941
#        SCONJ       0.81      0.90      0.85      2176
#          SYM       1.00      0.64      0.78        53
#         VERB       0.88      0.84      0.86     12617
#            X       0.31      0.05      0.08       105
#
#     accuracy                           0.89    115000
#    macro avg       0.79      0.75      0.76    115000
# weighted avg       0.88      0.89      0.88    115000
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# CountVectorizer(ngram_range=(1, 3))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          ADJ       0.95      0.37      0.54     11247
#          ADP       0.99      0.48      0.65     10255
#          ADV       0.93      0.78      0.85      5986
#          AUX       0.83      0.88      0.85      1058
#        CCONJ       0.90      0.20      0.33      4276
#          DET       0.83      0.69      0.75      2978
#         INTJ       0.00      0.00      0.00        11
#         NOUN       0.98      0.68      0.80     27241
#       NO_TAG       0.00      0.00      0.00       197
#          NUM       0.89      0.54      0.67      1436
#         PART       0.97      0.75      0.84      3762
#         PRON       0.81      0.82      0.82      5346
#        PROPN       0.94      0.14      0.24      4315
#        PUNCT       0.37      1.00      0.54     21941
#        SCONJ       0.78      0.78      0.78      2176
#          SYM       0.00      0.00      0.00        53
#         VERB       0.97      0.43      0.60     12617
#            X       0.00      0.00      0.00       105
#
#     accuracy                           0.64    115000
#    macro avg       0.67      0.47      0.51    115000
# weighted avg       0.83      0.64      0.65    115000
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# TfidfVectorizer(ngram_range=(1, 3))
#               precision    recall  f1-score   support
#
#          ADJ       0.95      0.44      0.60     11247
#          ADP       0.99      0.48      0.65     10255
#          ADV       0.96      0.80      0.87      5986
#          AUX       0.83      0.88      0.85      1058
#        CCONJ       0.89      0.20      0.33      4276
#          DET       0.75      0.84      0.79      2978
#         INTJ       0.00      0.00      0.00        11
#         NOUN       0.98      0.68      0.80     27241
#       NO_TAG       0.00      0.00      0.00       197
#          NUM       0.90      0.52      0.66      1436
#         PART       0.97      0.75      0.84      3762
#         PRON       0.88      0.76      0.81      5346
#        PROPN       0.94      0.14      0.24      4315
#        PUNCT       0.38      1.00      0.55     21941
#        SCONJ       0.79      0.85      0.82      2176
#          SYM       0.00      0.00      0.00        53
#         VERB       0.97      0.49      0.65     12617
#            X       0.00      0.00      0.00       105
#
#     accuracy                           0.66    115000
#    macro avg       0.68      0.49      0.53    115000
# weighted avg       0.84      0.66      0.67    115000
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# HashingVectorizer(n_features=1000, ngram_range=(1, 3))
#               precision    recall  f1-score   support
#
#          ADJ       0.43      0.21      0.28     11247
#          ADP       0.83      0.47      0.60     10255
#          ADV       0.59      0.63      0.61      5986
#          AUX       0.70      0.94      0.80      1058
#        CCONJ       0.84      0.18      0.30      4276
#          DET       0.49      0.55      0.52      2978
#         INTJ       0.00      0.00      0.00        11
#         NOUN       0.25      0.53      0.34     27241
#       NO_TAG       0.00      0.00      0.00       197
#          NUM       0.41      0.43      0.42      1436
#         PART       0.86      0.76      0.81      3762
#         PRON       0.64      0.76      0.70      5346
#        PROPN       0.32      0.08      0.13      4315
#        PUNCT       0.00      0.00      0.00     21941
#        SCONJ       0.67      0.95      0.78      2176
#          SYM       0.00      0.00      0.00        53
#         VERB       0.45      0.25      0.32     12617
#            X       0.00      0.00      0.00       105
#
#     accuracy                           0.37    115000
#    macro avg       0.42      0.38      0.37    115000
# weighted avg       0.39      0.37      0.35    115000
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# HashingVectorizer(analyzer='char', n_features=2000, ngram_range=(1, 3))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          ADJ       0.87      0.87      0.87     11247
#          ADP       0.98      0.99      0.98     10255
#          ADV       0.87      0.82      0.84      5986
#          AUX       0.81      0.97      0.88      1058
#        CCONJ       0.88      0.97      0.93      4276
#          DET       0.84      0.75      0.80      2978
#         INTJ       0.00      0.00      0.00        11
#         NOUN       0.86      0.93      0.89     27241
#       NO_TAG       1.00      1.00      1.00       197
#          NUM       0.83      0.84      0.83      1436
#         PART       0.94      0.78      0.85      3762
#         PRON       0.83      0.89      0.85      5346
#        PROPN       0.74      0.41      0.53      4315
#        PUNCT       1.00      1.00      1.00     21941
#        SCONJ       0.81      0.90      0.85      2176
#          SYM       1.00      0.64      0.78        53
#         VERB       0.89      0.88      0.89     12617
#            X       0.38      0.06      0.10       105
#
#     accuracy                           0.90    115000
#    macro avg       0.81      0.76      0.77    115000
# weighted avg       0.90      0.90      0.90    115000
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# HashingVectorizer(analyzer='char', n_features=3000, ngram_range=(1, 3))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          ADJ       0.87      0.87      0.87     11247
#          ADP       0.98      0.99      0.98     10255
#          ADV       0.88      0.82      0.85      5986
#          AUX       0.81      0.97      0.88      1058
#        CCONJ       0.88      0.98      0.93      4276
#          DET       0.82      0.80      0.81      2978
#         INTJ       0.00      0.00      0.00        11
#         NOUN       0.87      0.93      0.90     27241
#       NO_TAG       1.00      1.00      1.00       197
#          NUM       0.83      0.83      0.83      1436
#         PART       0.95      0.77      0.85      3762
#         PRON       0.84      0.87      0.85      5346
#        PROPN       0.75      0.40      0.52      4315
#        PUNCT       1.00      1.00      1.00     21941
#        SCONJ       0.81      0.90      0.85      2176
#          SYM       1.00      0.79      0.88        53
#         VERB       0.88      0.89      0.89     12617
#            X       0.28      0.10      0.15       105
#
#     accuracy                           0.90    115000
#    macro avg       0.80      0.77      0.78    115000
# weighted avg       0.90      0.90      0.90    115000
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# HashingVectorizer(analyzer='char', n_features=5000, ngram_range=(1, 3))
#               precision    recall  f1-score   support
#
#          ADJ       0.88      0.88      0.88     11247
#          ADP       0.98      0.99      0.98     10255
#          ADV       0.90      0.83      0.86      5986
#          AUX       0.81      0.97      0.88      1058
#        CCONJ       0.88      0.97      0.93      4276
#          DET       0.83      0.78      0.81      2978
#         INTJ       0.00      0.00      0.00        11
#         NOUN       0.87      0.94      0.90     27241
#       NO_TAG       1.00      1.00      1.00       197
#          NUM       0.84      0.87      0.85      1436
#         PART       0.94      0.78      0.85      3762
#         PRON       0.83      0.86      0.85      5346
#        PROPN       0.76      0.41      0.54      4315
#        PUNCT       1.00      1.00      1.00     21941
#        SCONJ       0.81      0.90      0.85      2176
#          SYM       1.00      0.64      0.78        53
#         VERB       0.89      0.90      0.89     12617
#            X       0.50      0.05      0.09       105
#
#     accuracy                           0.90    115000
#    macro avg       0.82      0.77      0.77    115000
# weighted avg       0.90      0.90      0.90    115000
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# HashingVectorizer(analyzer='char', n_features=10000, ngram_range=(1, 3))
#               precision    recall  f1-score   support
#
#          ADJ       0.88      0.88      0.88     11247
#          ADP       0.98      0.99      0.98     10255
#          ADV       0.90      0.84      0.87      5986
#          AUX       0.81      0.97      0.88      1058
#        CCONJ       0.88      0.97      0.93      4276
#          DET       0.83      0.78      0.81      2978
#         INTJ       0.00      0.00      0.00        11
#         NOUN       0.88      0.94      0.91     27241
#       NO_TAG       1.00      1.00      1.00       197
#          NUM       0.84      0.88      0.86      1436
#         PART       0.94      0.79      0.85      3762
#         PRON       0.82      0.87      0.85      5346
#        PROPN       0.78      0.42      0.54      4315
#        PUNCT       1.00      1.00      1.00     21941
#        SCONJ       0.82      0.86      0.84      2176
#          SYM       1.00      0.64      0.78        53
#         VERB       0.90      0.90      0.90     12617
#            X       0.71      0.05      0.09       105
#
#     accuracy                           0.91    115000
#    macro avg       0.83      0.77      0.78    115000
# weighted avg       0.91      0.91      0.90    115000
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# HashingVectorizer(n_features=2000, ngram_range=(1, 3))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          ADJ       0.50      0.26      0.34     11247
#          ADP       0.90      0.48      0.62     10255
#          ADV       0.68      0.69      0.68      5986
#          AUX       0.75      0.94      0.84      1058
#        CCONJ       0.89      0.18      0.31      4276
#          DET       0.67      0.53      0.59      2978
#         INTJ       0.00      0.00      0.00        11
#         NOUN       0.61      0.58      0.59     27241
#       NO_TAG       0.00      0.00      0.00       197
#          NUM       0.53      0.47      0.50      1436
#         PART       0.91      0.76      0.83      3762
#         PRON       0.69      0.85      0.76      5346
#        PROPN       0.39      0.10      0.15      4315
#        PUNCT       0.48      1.00      0.65     21941
#        SCONJ       0.76      0.90      0.82      2176
#          SYM       0.00      0.00      0.00        53
#         VERB       0.55      0.31      0.39     12617
#            X       0.00      0.00      0.00       105
#
#     accuracy                           0.58    115000
#    macro avg       0.52      0.45      0.45    115000
# weighted avg       0.62      0.58      0.56    115000
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# HashingVectorizer(n_features=3000, ngram_range=(1, 3))
#               precision    recall  f1-score   support
#
#          ADJ       0.55      0.30      0.39     11247
#          ADP       0.92      0.48      0.63     10255
#          ADV       0.77      0.71      0.74      5986
#          AUX       0.77      0.94      0.85      1058
#        CCONJ       0.93      0.18      0.30      4276
#          DET       0.71      0.57      0.63      2978
#         INTJ       0.00      0.00      0.00        11
#         NOUN       0.65      0.60      0.62     27241
#       NO_TAG       0.00      0.00      0.00       197
#          NUM       0.61      0.49      0.54      1436
#         PART       0.90      0.78      0.84      3762
#         PRON       0.74      0.83      0.79      5346
#        PROPN       0.44      0.12      0.18      4315
#        PUNCT       0.47      1.00      0.64     21941
#        SCONJ       0.73      0.95      0.83      2176
#          SYM       0.00      0.00      0.00        53
#         VERB       0.60      0.34      0.43     12617
#            X       0.00      0.00      0.00       105
#
#     accuracy                           0.60    115000
#    macro avg       0.54      0.46      0.47    115000
# weighted avg       0.65      0.60      0.58    115000
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# HashingVectorizer(n_features=5000, ngram_range=(1, 3))
#               precision    recall  f1-score   support
#
#          ADJ       0.63      0.33      0.44     11247
#          ADP       0.91      0.48      0.63     10255
#          ADV       0.82      0.72      0.77      5986
#          AUX       0.79      0.95      0.86      1058
#        CCONJ       0.92      0.19      0.31      4276
#          DET       0.69      0.70      0.70      2978
#         INTJ       0.00      0.00      0.00        11
#         NOUN       0.70      0.62      0.65     27241
#       NO_TAG       0.00      0.00      0.00       197
#          NUM       0.66      0.48      0.55      1436
#         PART       0.91      0.76      0.83      3762
#         PRON       0.79      0.79      0.79      5346
#        PROPN       0.54      0.13      0.21      4315
#        PUNCT       0.45      1.00      0.62     21941
#        SCONJ       0.76      0.88      0.82      2176
#          SYM       0.00      0.00      0.00        53
#         VERB       0.67      0.36      0.47     12617
#            X       0.00      0.00      0.00       105
#
#     accuracy                           0.61    115000
#    macro avg       0.57      0.47      0.48    115000
# weighted avg       0.68      0.61      0.59    115000
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# HashingVectorizer(n_features=10000, ngram_range=(1, 3))
#               precision    recall  f1-score   support
#
#          ADJ       0.72      0.37      0.48     11247
#          ADP       0.96      0.48      0.64     10255
#          ADV       0.88      0.75      0.81      5986
#          AUX       0.81      0.88      0.84      1058
#        CCONJ       0.88      0.20      0.33      4276
#          DET       0.72      0.75      0.74      2978
#         INTJ       0.00      0.00      0.00        11
#         NOUN       0.76      0.64      0.70     27241
#       NO_TAG       0.00      0.00      0.00       197
#          NUM       0.73      0.57      0.64      1436
#         PART       0.96      0.75      0.84      3762
#         PRON       0.83      0.78      0.81      5346
#        PROPN       0.67      0.15      0.24      4315
#        PUNCT       0.43      1.00      0.60     21941
#        SCONJ       0.78      0.88      0.83      2176
#          SYM       0.00      0.00      0.00        53
#         VERB       0.75      0.41      0.53     12617
#            X       0.00      0.00      0.00       105
#
#     accuracy                           0.63    115000
#    macro avg       0.60      0.48      0.50    115000
# weighted avg       0.72      0.63      0.62    115000
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
result_model = pd.DataFrame({'Vectorizer': vectorizers + vectorizers_word + hvectorizer + hvectorizer_word,
                            'f1_score': f1_scores})
result_model.sort_values('f1_score', ascending=False)
# Out:
#                                            Vectorizer  f1_score
# 0   CountVectorizer(analyzer='char', ngram_range=(...  0.927826
# 1   TfidfVectorizer(analyzer='char', ngram_range=(...  0.921158
# 9   HashingVectorizer(analyzer='char', n_features=...  0.903641
# 8   HashingVectorizer(analyzer='char', n_features=...  0.901192
# 7   HashingVectorizer(analyzer='char', n_features=...  0.896841
# 6   HashingVectorizer(analyzer='char', n_features=...  0.895273
# 2   HashingVectorizer(analyzer='char', n_features=...  0.882224
# 4                 TfidfVectorizer(ngram_range=(1, 3))  0.666235
# 3                 CountVectorizer(ngram_range=(1, 3))  0.649712
# 13  HashingVectorizer(n_features=10000, ngram_rang...  0.620867
# 12  HashingVectorizer(n_features=5000, ngram_range...  0.594828
# 11  HashingVectorizer(n_features=3000, ngram_range...  0.577216
# 10  HashingVectorizer(n_features=2000, ngram_range...  0.555762
# 5   HashingVectorizer(n_features=1000, ngram_range...  0.345039

# %%
result_model_acc = pd.DataFrame({'Vectorizer': vectorizers + vectorizers_word + hvectorizer + hvectorizer_word,
                            'Accuracy': acc_scores})
result_model_acc.sort_values('Accuracy', ascending=False)
# Out:
#                                            Vectorizer  Accuracy
# 0   CountVectorizer(analyzer='char', ngram_range=(...  0.929504
# 1   TfidfVectorizer(analyzer='char', ngram_range=(...  0.923583
# 9   HashingVectorizer(analyzer='char', n_features=...  0.907417
# 8   HashingVectorizer(analyzer='char', n_features=...  0.904974
# 7   HashingVectorizer(analyzer='char', n_features=...  0.900687
# 6   HashingVectorizer(analyzer='char', n_features=...  0.898939
# 2   HashingVectorizer(analyzer='char', n_features=...  0.885165
# 4                 TfidfVectorizer(ngram_range=(1, 3))  0.656504
# 3                 CountVectorizer(ngram_range=(1, 3))  0.641139
# 13  HashingVectorizer(n_features=10000, ngram_rang...  0.630722
# 12  HashingVectorizer(n_features=5000, ngram_range...  0.612913
# 11  HashingVectorizer(n_features=3000, ngram_range...  0.601217
# 10  HashingVectorizer(n_features=2000, ngram_range...  0.584009
# 5   HashingVectorizer(n_features=1000, ngram_range...  0.365243

# %% [markdown]
# Судя по результатам комбинации таггеров лидирует по Accuracy смесь из UnigramTagger & BigramTagger с результатом - 0.93
# Во втором и третьем тестах лидирует CountVectorizer с f-score 0.927826 и accuracy 0.929504

# %% [markdown]
# ### Задание 2.
# Проверить, насколько хорошо работает NER
# Данные брать из http://www.labinform.ru/pub/named_entities/
# проверить NER из nltk/spacy/deeppavlov.
# написать свой NER, попробовать разные подходы.
# передаём в сетку токен и его соседей.
# передаём в сетку только токен.
# свой вариант.
# сравнить свои реализованные подходы на качество — вывести precision/recall/f1_score.

# %%
# !pip install -U spacy
# !python -m spacy info
# !python -m spacy download ru_core_news_sm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.4)
# Collecting spacy
#   Downloading spacy-3.5.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 55.1 MB/s eta 0:00:00
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (21.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.11)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.6)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.25.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.0.1)
# Installing collected packages: spacy
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.4
#     Uninstalling spacy-3.4.4:
#       Successfully uninstalled spacy-3.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-sm 3.4.1 requires spacy<3.5.0,>=3.4.0, but you have spacy 3.5.0 which is incompatible.
# Successfully installed spacy-3.5.0
# /usr/local/lib/python3.8/dist-packages/spacy/util.py:877: UserWarning: [W095] Model 'en_core_web_sm' (3.4.1) was trained with spaCy v3.4 and may not be 100% compatible with the current version (3.5.0). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
#
# ============================== Info about spaCy ==============================
#
# spaCy version    3.5.0
# Location         /usr/local/lib/python3.8/dist-packages/spacy
# Platform         Linux-5.10.147+-x86_64-with-glibc2.29
# Python version   3.8.10
# Pipelines        en_core_web_sm (3.4.1)
#
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ru-core-news-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.5.0/ru_core_news_sm-3.5.0-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 34.3 MB/s eta 0:00:00
# Collecting pymorphy3>=1.0.0
#   Downloading pymorphy3-1.2.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 KB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.8/dist-packages (from ru-core-news-sm==3.5.0) (3.5.0)
# Collecting pymorphy3-dicts-ru
#   Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 69.9 MB/s eta 0:00:00
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting docopt>=0.6
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.7.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.0.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.10.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (4.64.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (8.1.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.11)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.11.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.25.1)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (21.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (6.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (57.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.21.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.4.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (4.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.1)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=9a8e00eb6defb383d89636a27301c6de71fdce8bfa885034d441db6da2945a5a
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built docopt
# Installing collected packages: pymorphy3-dicts-ru, docopt, dawg-python, pymorphy3, ru-core-news-sm
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy3-1.2.0 pymorphy3-dicts-ru-2.4.417150.4580142 ru-core-news-sm-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')

# %%
# !pip install navec
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting navec
#   Downloading navec-0.10.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from navec) (1.21.6)
# Installing collected packages: navec
# Successfully installed navec-0.10.0

# %%
# !pip install slovnet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting slovnet
#   Downloading slovnet-0.6.0-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 KB 2.0 MB/s eta 0:00:00
# Collecting razdel
#   Downloading razdel-0.5.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: navec in /usr/local/lib/python3.8/dist-packages (from slovnet) (0.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from slovnet) (1.21.6)
# Installing collected packages: razdel, slovnet
# Successfully installed razdel-0.5.0 slovnet-0.6.0

# %%
# !pip install ipymarkup
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ipymarkup
#   Downloading ipymarkup-0.9.0-py3-none-any.whl (14 kB)
# Collecting intervaltree>=3
#   Downloading intervaltree-3.1.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from intervaltree>=3->ipymarkup) (2.4.0)
# Building wheels for collected packages: intervaltree
#   Building wheel for intervaltree (setup.py) ... done
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26118 sha256=5daed93618eb5790cdeebb836da44a2c5161086ab3ae7f118fb5d39ef5ef778a
#   Stored in directory: /root/.cache/pip/wheels/45/23/de/5789a92962483fd33cb06674792b9697c1b3766d7c7742830e
# Successfully built intervaltree
# Installing collected packages: intervaltree, ipymarkup
#   Attempting uninstall: intervaltree
#     Found existing installation: intervaltree 2.1.0
#     Uninstalling intervaltree-2.1.0:
#       Successfully uninstalled intervaltree-2.1.0
# Successfully installed intervaltree-3.1.0 ipymarkup-0.9.0

# %%
# !pip install sklearn_crfsuite
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sklearn_crfsuite
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Collecting python-crfsuite>=0.8.3
#   Downloading python_crfsuite-0.9.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.7 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from sklearn_crfsuite) (1.15.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.8/dist-packages (from sklearn_crfsuite) (4.64.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.8/dist-packages (from sklearn_crfsuite) (0.8.10)
# Installing collected packages: python-crfsuite, sklearn_crfsuite
# Successfully installed python-crfsuite-0.9.8 sklearn_crfsuite-0.3.6

# %%
# !pip install patool
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting patool
#   Downloading patool-1.12-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 KB 3.9 MB/s eta 0:00:00
# Installing collected packages: patool
# Successfully installed patool-1.12

# %%
import os
import glob

import csv
from razdel import tokenize

from spacy import displacy
import ru_core_news_sm

from navec import Navec
from slovnet import NER
from ipymarkup import show_span_ascii_markup as show_markup

import sklearn_crfsuite
from sklearn_crfsuite import metrics

# %%
import patoolib
patoolib.extract_archive("collection3.zip", outdir="collection3")
# Out:
# patool: Extracting collection3.zip ...
# patool: running /usr/bin/7z x -ocollection3 -- collection3.zip
# patool: ... collection3.zip extracted to `collection3'.
# 'collection3'

# %%
fileDir = r"collection3"
fileExt = r".txt"
documents_txt = [_ for _ in os.listdir(fileDir) if _.endswith(fileExt)]
text_list = []
for file in documents_txt:
    doc = open('collection3/' + file, encoding='utf-8')
    text = doc.read()
    text_list.append(text)
    
data_text = pd.DataFrame({'text': text_list })
data_text
# Out:
#                                                   text
# 0    Совмин Белоруссии надеется разгрузить склады в...
# 1    Продолжаются увольнения энергетиков после крит...
# 2    \nЭкс-Президенту Египта Мурси продлили срок ар...
# 3    Медведев уволил Суходольского с должности глав...
# 4    Сын А.Лукашенко взял нити силовых структур в с...
# ..                                                 ...
# 719  СМИ назвали имя лидера "Октябрьского джамаата"...
# 720  Бывший председатель Банка России сменит Кудрин...
# 721  Антонова приветствует назначение Лошак на пост...
# 722  У пензенского Роскомнадзора новый глава\n\t\nА...
# 723  В.Путин уволил замминистра промышленности и то...
#
# [724 rows x 1 columns]

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
document = data_text.text[0]
nltk.pos_tag(nltk.word_tokenize(document))
# Out:
# [('Совмин', 'JJ'),
#  ('Белоруссии', 'NNP'),
#  ('надеется', 'NNP'),
#  ('разгрузить', 'NNP'),
#  ('склады', 'NNP'),
#  ('в', 'NNP'),
#  ('Сибири', 'NNP'),
#  ('Скопившаяся', 'NNP'),
#  ('на', 'NNP'),
#  ('складах', 'NNP'),
#  ('белорусских', 'NNP'),
#  ('предприятий', 'NNP'),
#  ('продукция', 'NNP'),
#  ('может', 'NNP'),
#  ('быть', 'NNP'),
#  ('реализована', 'NNP'),
#  ('в', 'NNP'),
#  ('Сибири', 'NNP'),
#  ('при', 'NNP'),
#  ('помощи', 'NNP'),
#  ('административного', 'NNP'),
#  ('ресурса', 'NNP'),
#  ('российских', 'NNP'),
#  ('чиновников', 'NNP'),
#  ('.', '.'),
#  ('Об', 'VB'),
#  ('этом', 'JJ'),
#  ('17', 'CD'),
#  ('июня', 'JJ'),
#  ('заявил', 'NNP'),
#  ('председатель', 'NNP'),
#  ('правительства', 'NNP'),
#  ('Белоруссии', 'NNP'),
#  ('Михаил', 'NNP'),
#  ('Мясникович', 'NNP'),
#  ('на', 'NNP'),
#  ('встрече', 'NNP'),
#  ('с', 'NNP'),
#  ('делегацией', 'NNP'),
#  ('Сибирского', 'NNP'),
#  ('федерального', 'NNP'),
#  ('округа', 'NNP'),
#  ('России', 'NNP'),
#  ('во', 'NNP'),
#  ('главе', 'NNP'),
#  ('с', 'NNP'),
#  ('полномочным', 'NNP'),
#  ('представителем', 'NNP'),
#  ('президента', 'NNP'),
#  ('РФ', 'NNP'),
#  ('Виктором', 'NNP'),
#  ('Толоконским', 'NNP'),
#  ('.', '.'),
#  ('Во', 'VB'),
#  ('время', 'JJ'),
#  ('встречи', 'NNP'),
#  ('Мясникович', 'NNP'),
#  ('указал', 'NNP'),
#  ('на', 'NNP'),
#  ('``', '``'),
#  ('огромный', 'FW'),
#  ('потенциал', 'NN'),
#  ("''", "''"),
#  ('сотрудничества', 'CC'),
#  ('Белоруссии', 'NNP'),
#  ('с', 'NNP'),
#  ('Сибирским', 'NNP'),
#  ('федеральным', 'NNP'),
#  ('округом', 'NN'),
#  (':', ':'),
#  ('по', 'NN'),
#  ('итогам', 'NN'),
#  ('2012', 'CD'),
#  ('года', 'NNP'),
#  ('взаимный', 'NNP'),
#  ('товарооборот', 'NNP'),
#  ('составил', 'NNP'),
#  ('более', 'NNP'),
#  ('$', '$'),
#  ('1,4', 'CD'),
#  ('млрд', 'NNP'),
#  ('-', ':'),
#  ('на', 'RB'),
#  ('4,4', 'CD'),
#  ('%', 'NN'),
#  ('больше', 'NN'),
#  ('уровня', 'NN'),
#  ('2011', 'CD'),
#  ('года', 'NN'),
#  ('.', '.'),
#  ('Председатель', 'CC'),
#  ('Совмина', 'JJ'),
#  ('Белоруссии', 'NNP'),
#  ('с', 'NNP'),
#  ('сожалением', 'NNP'),
#  ('отметил', 'NN'),
#  (':', ':'),
#  ('в', 'NN'),
#  ('I', 'PRP'),
#  ('квартале', 'VBP'),
#  ('2013', 'CD'),
#  ('года', 'NNP'),
#  ('объемы', 'NNP'),
#  ('поставок', 'NNP'),
#  ('снизились', 'NNP'),
#  ('на', 'VBD'),
#  ('30', 'CD'),
#  ('%', 'NN'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('т.ч', 'NNP'),
#  ('.', '.'),
#  ('за', 'VB'),
#  ('счёт', 'JJ'),
#  ('снижения', 'NNP'),
#  ('экспорта', 'NNP'),
#  ('белорусских', 'NNP'),
#  ('грузовиков', 'NNP'),
#  ('и', 'NNP'),
#  ('ряда', 'NNP'),
#  ('другой', 'NNP'),
#  ('техники', 'NNP'),
#  ('.', '.'),
#  ('Мясникович', 'VB'),
#  ('обратился', 'JJ'),
#  ('к', 'NNP'),
#  ('полномочному', 'NNP'),
#  ('представителю', 'NNP'),
#  ('президента', 'NNP'),
#  ('РФ', 'NNP'),
#  ('с', 'NNP'),
#  ('просьбой', 'NNP'),
#  ('``', '``'),
#  ('подтолкнуть', 'NN'),
#  ("''", "''"),
#  ('российские', 'CC'),
#  ('компании', 'NNP'),
#  ('к', 'NNP'),
#  ('активизации', 'NNP'),
#  ('закупок', 'NNP'),
#  ('белорусской', 'NNP'),
#  ('техники', 'NNP'),
#  (',', ','),
#  ('скопившейся', 'NNP'),
#  ('на', 'NNP'),
#  ('складах', 'NNP'),
#  ('Белоруссии', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('вызывает', 'NNP'),
#  ('целый', 'NNP'),
#  ('ряд', 'NNP'),
#  ('проблем', 'NNP'),
#  ('для', 'NNP'),
#  ('руководства', 'NNP'),
#  ('республики', 'NNP'),
#  ('.', '.'),
#  ('Напомним', 'NN'),
#  (',', ','),
#  ('11', 'CD'),
#  ('июня', 'NN'),
#  ('на', 'NNP'),
#  ('совещании', 'NNP'),
#  ('по', 'NNP'),
#  ('вопросам', 'NNP'),
#  ('развития', 'NNP'),
#  ('промышленного', 'NNP'),
#  ('комплекса', 'NNP'),
#  ('и', 'NNP'),
#  ('реализации', 'NNP'),
#  ('белорусской', 'NNP'),
#  ('продукции', 'NNP'),
#  ('в', 'NNP'),
#  ('Администрации', 'NNP'),
#  ('президента', 'NNP'),
#  ('Белоруссии', 'NNP'),
#  ('Александр', 'NNP'),
#  ('Лукашенко', 'NNP'),
#  ('подверг', 'NNP'),
#  ('резкой', 'NNP'),
#  ('критике', 'NNP'),
#  ('состояние', 'NNP'),
#  ('дел', 'NNP'),
#  ('в', 'NNP'),
#  ('белорусской', 'NNP'),
#  ('экономике', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('в', 'JJ'),
#  ('очередной', 'NNP'),
#  ('раз', 'NNP'),
#  ('распорядился', 'NNP'),
#  ('в', 'NNP'),
#  ('течение', 'NNP'),
#  ('лета', 'NNP'),
#  ('``', '``'),
#  ('разгрузить', 'FW'),
#  ('склады', 'NN'),
#  ("''", "''"),
#  ('предприятий', 'NN'),
#  ('республики', 'NNP'),
#  (',', ','),
#  ('не', 'NNP'),
#  ('приняв', 'NNP'),
#  ('ссылки', 'NNP'),
#  ('чиновников', 'NNP'),
#  ('на', 'NNP'),
#  ('вступление', 'NNP'),
#  ('России', 'NNP'),
#  ('в', 'NNP'),
#  ('ВТО', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('осложнило', 'NNP'),
#  ('реализацию', 'NNP'),
#  ('белорусской', 'NNP'),
#  ('продукции', 'NNP'),
#  ('на', 'NNP'),
#  ('российском', 'NNP'),
#  ('рынке', 'NNP'),
#  ('из-за', 'JJ'),
#  ('возросшей', 'NNP'),
#  ('конкуренции', 'NNP'),
#  ('.', '.'),
#  ('Мясникович', 'VB'),
#  ('обратил', 'JJ'),
#  ('внимание', 'NNP'),
#  ('российской', 'NNP'),
#  ('делегации', 'NN'),
#  (':', ':'),
#  ('наличие', 'JJ'),
#  ('инфраструктуры', 'NNP'),
#  ('по', 'NNP'),
#  ('созданию', 'NNP'),
#  ('совместных', 'NNP'),
#  ('предприятий', 'NNP'),
#  ('способствует', 'NNP'),
#  ('решению', 'NNP'),
#  ('многих', 'NNP'),
#  ('других', 'NNP'),
#  ('вопросов', 'NNP'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Поэтому', 'JJ'),
#  ('у', 'NN'),
#  ('меня', 'NNP'),
#  ('такое', 'NNP'),
#  ('предложение', 'NN'),
#  (':', ':'),
#  ('давайте', 'JJ'),
#  ('строить', 'NNP'),
#  ('дальнейшую', 'NNP'),
#  ('работу', 'NNP'),
#  ('в', 'NNP'),
#  ('основном', 'NNP'),
#  ('на', 'NNP'),
#  ('том', 'NNP'),
#  (',', ','),
#  ('чтобы', 'NNP'),
#  ('были', 'NNP'),
#  ('совместные', 'NNP'),
#  ('предприятия', 'NNP'),
#  ('и', 'NNP'),
#  ('формировалась', 'NNP'),
#  ('соответствующая', 'NNP'),
#  ('добавленная', 'NNP'),
#  ('стоимость', 'NNP'),
#  (',', ','),
#  ('в', 'NNP'),
#  ('этом', 'NNP'),
#  ('интерес', 'NNP'),
#  ('будет', 'NNP'),
#  ('у', 'NNP'),
#  ('всех', 'NNP'),
#  ('.', '.'),
#  ('И', 'NN'),
#  ('главное', 'NN'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('мы', 'NNP'),
#  ('будем', 'NNP'),
#  ('чувствовать', 'NNP'),
#  ('друг', 'NNP'),
#  ('друга', 'NNP'),
#  (',', ','),
#  ('какие', 'NNP'),
#  ('есть', 'NNP'),
#  ('проблемы', 'NNP'),
#  ('у', 'NNP'),
#  ('каждого', 'NNP'),
#  ("''", "''"),
#  (',', ','),
#  ('-', ':'),
#  ('сказал', 'NN'),
#  ('он', 'NN'),
#  ('.', '.'),
#  ('Мясникович', 'CC'),
#  ('предложил', 'JJ'),
#  ('решение', 'NNP'),
#  ('данного', 'NNP'),
#  ('вопроса', 'NN'),
#  (':', ':'),
#  ('``', '``'),
#  ('Может', 'FW'),
#  ('быть', 'NN'),
#  (',', ','),
#  ('нам', 'NNP'),
#  ('стоит', 'NNP'),
#  ('создать', 'NNP'),
#  ('фонд', 'NNP'),
#  (',', ','),
#  ('выйти', 'NNP'),
#  ('на', 'NNP'),
#  ('создание', 'NNP'),
#  ('совместной', 'NNP'),
#  ('инжиниринговой', 'NNP'),
#  ('компании', 'NNP'),
#  (',', ','),
#  ('то', 'NNP'),
#  ('есть', 'NNP'),
#  ('это', 'NNP'),
#  ('будет', 'NNP'),
#  ('юридическое', 'NNP'),
#  ('лицо', 'NNP'),
#  (',', ','),
#  ('небольшое', 'NNP'),
#  ('по', 'NNP'),
#  ('численности', 'NNP'),
#  ("''", "''"),
#  ('.', '.'),
#  ('В', 'VB'),
#  ('свою', 'JJ'),
#  ('очередь', 'NNP'),
#  ('Толоконский', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('сообщает', 'NNP'),
#  ('пресс-служба', 'JJ'),
#  ('Совмина', 'NNP'),
#  ('Белоруссии', 'NNP'),
#  (',', ','),
#  ('выразил', 'NNP'),
#  ('уверенность', 'NNP'),
#  ('в', 'NNP'),
#  ('том', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('руководители', 'NNP'),
#  ('регионов', 'NNP'),
#  ('СФО', 'NNP'),
#  ('активно', 'NNP'),
#  ('подключатся', 'NNP'),
#  ('к', 'NNP'),
#  ('выполнению', 'NNP'),
#  ('поставленных', 'NNP'),
#  ('перед', 'NNP'),
#  ('ними', 'NNP'),
#  ('задач', 'NNP'),
#  (',', ','),
#  ('хотя', 'NNP'),
#  ('в', 'NNP'),
#  ('России', 'NNP'),
#  (',', ','),
#  ('как', 'NNP'),
#  ('и', 'NNP'),
#  ('в', 'NNP'),
#  ('Белоруссии', 'NNP'),
#  (',', ','),
#  ('и', 'NNP'),
#  ('других', 'NNP'),
#  ('странах', 'NNP'),
#  ('наблюдается', 'NNP'),
#  ('экономический', 'NNP'),
#  ('спад', 'NNP'),
#  ('.', '.'),
#  ('Полпред', 'VB'),
#  ('президента', 'JJ'),
#  ('РФ', 'JJ'),
#  ('пояснил', 'NN'),
#  (':', ':'),
#  ('``', '``'),
#  ('Мы', 'FW'),
#  ('не', 'FW'),
#  ('потому', 'FW'),
#  ('сократили', 'FW'),
#  ('закупки', 'FW'),
#  ('белорусской', 'FW'),
#  ('техники', 'FW'),
#  (',', ','),
#  ('что', 'FW'),
#  ('в', 'FW'),
#  ('чем-то', 'JJ'),
#  ('сомневаемся', 'NNP'),
#  ('или', 'NNP'),
#  ('есть', 'NNP'),
#  ('какие-то', 'JJ'),
#  ('другие', 'NNP'),
#  ('претенденты', 'NNP'),
#  ('на', 'NNP'),
#  ('это', 'NNP'),
#  ('сотрудничество', 'NNP'),
#  (',', ','),
#  ('просто', 'NNP'),
#  ('серьезно', 'NNP'),
#  ('осложнилась', 'NNP'),
#  ('ситуация', 'NNP'),
#  ('в', 'NNP'),
#  ('угольной', 'NNP'),
#  ('промышленности', 'NNP'),
#  (',', ','),
#  ('произошло', 'NNP'),
#  ('падение', 'NNP'),
#  ('мировых', 'NNP'),
#  ('экспортных', 'NNP'),
#  ('цен', 'NNP'),
#  ('на', 'NNP'),
#  ('сырье', 'NNP'),
#  ("''", "''"),
#  ('.', '.'),
#  ('Как', 'VB'),
#  ('сообщало', 'JJ'),
#  ('ИА', 'NNP'),
#  ('REGNUM', 'NNP'),
#  (',', ','),
#  ('17', 'CD'),
#  ('июня', 'NN'),
#  ('в', 'NNP'),
#  ('Минске', 'NNP'),
#  ('Александр', 'NNP'),
#  ('Лукашенко', 'NNP'),
#  ('во', 'NNP'),
#  ('время', 'NNP'),
#  ('встречи', 'NNP'),
#  ('с', 'NNP'),
#  ('российской', 'NNP'),
#  ('делегацией', 'NNP'),
#  ('во', 'NNP'),
#  ('главе', 'NNP'),
#  ('с', 'NNP'),
#  ('полномочным', 'NNP'),
#  ('представителем', 'NNP'),
#  ('президента', 'NNP'),
#  ('России', 'NNP'),
#  ('в', 'NNP'),
#  ('Сибирском', 'NNP'),
#  ('федеральном', 'NNP'),
#  ('округе', 'NNP'),
#  ('Виктором', 'NNP'),
#  ('Толоконским', 'NNP'),
#  ('заявил', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('развитие', 'NNP'),
#  ('прямых', 'NNP'),
#  ('экономических', 'NNP'),
#  ('связей', 'NNP'),
#  ('Белоруссии', 'NNP'),
#  ('с', 'NNP'),
#  ('российскими', 'NNP'),
#  ('регионами', 'NNP'),
#  ('является', 'NNP'),
#  ('основой', 'NNP'),
#  ('успешного', 'NNP'),
#  ('развития', 'NNP'),
#  ('межгосударственных', 'NNP'),
#  ('интеграционных', 'NNP'),
#  ('отношений', 'NNP'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Время', 'JJ'),
#  ('сегодня', 'NN'),
#  ('такое', 'NN'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('весь', 'NNP'),
#  ('мир', 'NNP'),
#  ('в', 'NNP'),
#  ('кризисе', 'NNP'),
#  ('.', '.'),
#  ('И', 'NN'),
#  ('надеяться', 'NN'),
#  (',', ','),
#  ('уповать', 'NNP'),
#  ('на', 'NNP'),
#  ('этот', 'NNP'),
#  ('мир', 'NNP'),
#  ('далёкий', 'NNP'),
#  (',', ','),
#  ('нам', 'NNP'),
#  ('нечего', 'NNP'),
#  (',', ','),
#  ('-', ':'),
#  ('сказал', 'NN'),
#  ('Лукашенко', 'NN'),
#  (',', ','),
#  ('обращаясь', 'NNP'),
#  ('к', 'NNP'),
#  ('делегации', 'NNP'),
#  ('из', 'NNP'),
#  ('Сибири', 'NNP'),
#  ('.', '.'),
#  ('-', ':'),
#  ('У', 'NN'),
#  ('нас', 'JJ'),
#  ('есть', 'NNP'),
#  ('опыт', 'NNP'),
#  ('сотрудничества', 'NNP'),
#  ('в', 'NNP'),
#  ('одном', 'NNP'),
#  ('государстве', 'NNP'),
#  ('.', '.'),
#  ('Поэтому', 'VB'),
#  ('давайте', 'JJ'),
#  ('будем', 'NNP'),
#  (',', ','),
#  ('основываясь', 'NNP'),
#  ('на', 'NNP'),
#  ('нашем', 'NNP'),
#  ('опыте', 'NNP'),
#  (',', ','),
#  ('двигаться', 'NNP'),
#  ('вперёд', 'NNP'),
#  ("''", "''"),
#  ('.', '.'),
#  ('Лукашенко', 'VB'),
#  ('обратил', 'JJ'),
#  ('внимание', 'NNP'),
#  ('членов', 'NNP'),
#  ('российской', 'NNP'),
#  ('делегации', 'NNP'),
#  ('на', 'NNP'),
#  ('необходимость', 'NNP'),
#  ('наращивания', 'NNP'),
#  ('взаимной', 'NNP'),
#  ('торговли', 'NNP'),
#  ('с', 'NNP'),
#  ('повышением', 'NNP'),
#  ('доли', 'NNP'),
#  ('высокотехнологичной', 'NNP'),
#  ('и', 'NNP'),
#  ('наукоемкой', 'NNP'),
#  ('продукции', 'NNP'),
#  (',', ','),
#  ('а', 'NNP'),
#  ('также', 'NNP'),
#  ('услуг', 'NNP'),
#  ('.', '.'),
#  ('В', 'NN'),
#  ('частности', 'NN'),
#  (',', ','),
#  ('отметил', 'NNP'),
#  ('он', 'NNP'),
#  (',', ','),
#  ('строители', 'NNP'),
#  ('из', 'NNP'),
#  ('Белоруссии', 'NNP'),
#  ('могли', 'NNP'),
#  ('бы', 'NNP'),
#  ('привлекаться', 'NNP'),
#  ('к', 'NNP'),
#  ('реализации', 'NNP'),
#  ('проектов', 'NNP'),
#  ('в', 'NNP'),
#  ('Сибири', 'NNP'),
#  ('.', '.'),
#  ('Он', 'VB'),
#  ('также', 'JJ'),
#  ('считает', 'NNP'),
#  (',', ','),
#  ('что', 'NNP'),
#  ('белорусские', 'NNP'),
#  ('специалисты', 'NNP'),
#  ('могли', 'NNP'),
#  ('бы', 'NNP'),
#  ('участвовать', 'NNP'),
#  ('в', 'NNP'),
#  ('добыче', 'NNP'),
#  ('природных', 'NNP'),
#  ('ресурсов', 'NNP'),
#  ('Сибири', 'NNP'),
#  (',', ','),
#  ('работать', 'NNP'),
#  ('в', 'NNP'),
#  ('сферах', 'NNP'),
#  ('сельского', 'NNP'),
#  (',', ','),
#  ('коммунального', 'NNP'),
#  ('и', 'NNP'),
#  ('лесного', 'NNP'),
#  ('хозяйства', 'NNP'),
#  ('СФО', 'NNP'),
#  (',', ','),
#  ('участвовать', 'NNP'),
#  ('в', 'NNP'),
#  ('совместных', 'NNP'),
#  ('научно-технических', 'JJ'),
#  ('проектах', 'NN'),
#  ('.', '.')]

# %%
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
{(' '.join(c[0] for c in chunk), chunk.label() ) for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(document))) if hasattr(chunk, 'label') }
# Out:
# {('Белоруссии', 'ORGANIZATION'),
#  ('Белоруссии', 'PERSON'),
#  ('Лукашенко', 'PERSON'),
#  ('Минске Александр Лукашенко', 'PERSON'),
#  ('Михаил Мясникович', 'PERSON'),
#  ('Напомним', 'PERSON'),
#  ('России', 'PERSON'),
#  ('Сибири', 'PERSON'),
#  ('Сибири Скопившаяся', 'PERSON'),
#  ('Совмин', 'PERSON'),
#  ('Совмина Белоруссии', 'PERSON')}

# %%
pd.read_csv('collection3/001.ann', delimiter='\t')
# Out:
#      T1      LOC 0 6            Россия
# 0    T2    LOC 50 53               США
# 1    T3    LOC 57 63            Грузию
# 2    T4    LOC 87 93            МОСКВА
# 3    T5  ORG 103 114       РИА Новости
# 4    T6  LOC 116 122            Россия
# 5    T7  LOC 141 144               США
# 6    T8  LOC 161 168           Тбилиси
# 7    T9  LOC 301 307            России
# 8   T10  PER 308 324  Григорий Карасин
# 9   T11  LOC 383 386               США
# 10  T12  PER 387 402   Дэниэлом Фридом
# 11  T13  LOC 505 517      Южной Осетии
# 12  T14  LOC 703 709            Россия
# 13  T15  LOC 723 730           Тбилиси
# 14  T16  LOC 815 825        Вашингтона
# 15  T17  ORG 838 841               МИД
# 16  T18  LOC 842 848            России

# %%
nlp = ru_core_news_sm.load()
ny_bb = data_text.text[0]
article = nlp(ny_bb)
displacy.render(article, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Совмин
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Белоруссии
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  надеется разгрузить склады в
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Сибири
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </br></br>Скопившаяся на складах белорусских предприятий продукция может быть реализована в
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Сибири
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  при помощи административного ресурса российских чиновников. Об этом 17 июня заявил председатель правительства
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Белоруссии
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Михаил Мясникович
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  на встрече с делегацией
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Сибирского федерального округа
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     России
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  во главе с полномочным представителем президента
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     РФ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Виктором Толоконским
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# .</br></br>Во время встречи
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Мясникович
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  указал на &quot;огромный потенциал&quot; сотрудничества
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Белоруссии
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  с
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Сибирским федеральным округом
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# : по итогам 2012 года взаимный товарооборот составил более $1,4 млрд - на 4,4% больше уровня 2011 года. Председатель
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Совмина
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Белоруссии
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  с сожалением отметил: в I квартале 2013 года объемы поставок снизились на 30%, в т.ч. за счёт снижения экспорта белорусских грузовиков и ряда другой техники.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Мясникович
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  обратился к полномочному представителю президента
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     РФ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  с просьбой &quot;подтолкнуть&quot; российские компании к активизации закупок белорусской техники, скопившейся на складах
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Белоруссии
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , что вызывает целый ряд проблем для руководства республики.</br></br>Напомним, 11 июня на совещании по вопросам развития промышленного комплекса и реализации белорусской продукции в
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Администрации президента
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Белоруссии
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Александр Лукашенко
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  подверг резкой критике состояние дел в белорусской экономике. Он в очередной раз распорядился в течение лета &quot;разгрузить склады&quot; предприятий республики, не приняв ссылки чиновников на вступление
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     России
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  в
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ВТО
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align:

# %%
for token in article:
    print(token.text, token.pos_, token.dep_)
# Out:
# Совмин NOUN nsubj
# Белоруссии PROPN nmod
# надеется VERB ROOT
# разгрузить VERB xcomp
# склады NOUN obj
# в ADP case
# Сибири PROPN nmod
#
#
#  SPACE dep
# Скопившаяся VERB acl
# на ADP case
# складах NOUN obl
# белорусских ADJ amod
# предприятий NOUN nmod
# продукция NOUN nsubj:pass
# может VERB parataxis
# быть AUX aux:pass
# реализована VERB xcomp
# в ADP case
# Сибири PROPN obl
# при ADP case
# помощи NOUN fixed
# административного ADJ amod
# ресурса NOUN obl
# российских ADJ amod
# чиновников NOUN nmod
# . PUNCT punct
# Об ADP case
# этом PRON obl
# 17 ADJ obl
# июня NOUN flat
# заявил VERB ROOT
# председатель NOUN nsubj
# правительства NOUN nmod
# Белоруссии PROPN nmod
# Михаил PROPN appos
# Мясникович PROPN flat:name
# на ADP case
# встрече NOUN obl
# с ADP case
# делегацией NOUN nmod
# Сибирского ADJ amod
# федерального ADJ amod
# округа NOUN nmod
# России PROPN nmod
# во ADP case
# главе NOUN fixed
# с ADP case
# полномочным ADJ amod
# представителем NOUN obl
# президента NOUN nmod
# РФ PROPN nmod
# Виктором PROPN appos
# Толоконским PROPN flat:name
# . PUNCT punct
#
#
#  SPACE dep
# Во ADP case
# время NOUN fixed
# встречи NOUN obl
# Мясникович PROPN nsubj
# указал VERB ROOT
# на ADP case
# " PUNCT punct
# огромный ADJ amod
# потенциал NOUN obl
# " PUNCT punct
# сотрудничества NOUN nmod
# Белоруссии PROPN nmod
# с ADP case
# Сибирским ADJ amod
# федеральным ADJ amod
# округом NOUN nmod
# : PUNCT punct
# по ADP case
# итогам NOUN obl
# 2012 ADJ amod
# года NOUN nmod
# взаимный ADJ amod
# товарооборот NOUN nsubj
# составил VERB parataxis
# более ADV advmod
# $ SYM obj
# 1,4 NUM appos
# млрд NOUN obj
# - NOUN obj
# на ADP case
# 4,4 NUM nummod
# % SYM obl
# больше NUM conj
# уровня NOUN obl
# 2011 ADJ amod
# года NOUN nmod
# . PUNCT punct
# Председатель NOUN nsubj
# Совмина PROPN nmod
# Белоруссии PROPN nmod
# с ADP case
# сожалением NOUN obl
# отметил VERB ROOT
# : PUNCT punct
# в ADP case
# I ADJ amod
# квартале NOUN obl
# 2013 ADJ amod
# года NOUN nmod
# объемы NOUN nsubj
# поставок NOUN nmod
# снизились VERB parataxis
# на ADP case
# 30 NUM nummod
# % SYM obl
# , PUNCT punct
# в т.ч. PROPN conj
# за ADP case
# счёт ADJ amod
# снижения NOUN obl
# экспорта NOUN nmod
# белорусских ADJ amod
# грузовиков NOUN nmod
# и CCONJ cc
# ряда NOUN conj
# другой ADJ amod
# техники NOUN nmod
# . PUNCT punct
# Мясникович PROPN nsubj
# обратился VERB ROOT
# к ADP case
# полномочному ADJ amod
# представителю NOUN obl
# президента NOUN nmod
# РФ PROPN nmod
# с ADP case
# просьбой NOUN obl
# " PUNCT punct
# подтолкнуть VERB nmod
# " PUNCT punct
# российские ADJ amod
# компании NOUN obj
# к ADP case
# активизации NOUN obl
# закупок NOUN nmod
# белорусской ADJ amod
# техники NOUN nmod
# , PUNCT punct
# скопившейся VERB acl
# на ADP case
# складах NOUN obl
# Белоруссии PROPN nmod
# , PUNCT punct
# что PRON nsubj
# вызывает VERB parataxis
# целый ADJ amod
# ряд NOUN obj
# проблем NOUN nmod
# для ADP case
# руководства NOUN nmod
# республики NOUN nmod
# . PUNCT punct
#
#
#  SPACE dep
# Напомним VERB parataxis
# , PUNCT punct
# 11 ADJ obl
# июня NOUN flat
# на ADP case
# совещании NOUN obl
# по ADP case
# вопросам NOUN nmod
# развития NOUN nmod
# промышленного ADJ amod
# комплекса NOUN nmod
# и CCONJ cc
# реализации NOUN conj
# белорусской ADJ amod
# продукции NOUN nmod
# в ADP case
# Администрации PROPN nmod
# президента NOUN nmod
# Белоруссии PROPN nmod
# Александр PROPN appos
# Лукашенко PROPN flat:name
# подверг VERB ROOT
# резкой ADJ amod
# критике NOUN iobj
# состояние NOUN obj
# дел NOUN nmod
# в ADP case
# белорусской ADJ amod
# экономике NOUN nmod
# . PUNCT punct
# Он PRON nsubj
# в ADP case
# очередной ADJ amod
# раз NOUN obl
# распорядился VERB ROOT
# в ADP case
# течение NOUN fixed
# лета NOUN obl
# " PUNCT punct
# разгрузить VERB xcomp
# склады NOUN obj
# " PUNCT punct
# предприятий NOUN nmod
# республики NOUN nmod
# , PUNCT punct
# не PART advmod
# приняв VERB advcl
# ссылки NOUN obj
# чиновников NOUN nmod
# на ADP case
# вступление NOUN nmod
# России PROPN nmod
# в ADP case
# ВТО PROPN nmod
# , PUNCT punct
# что PRON nsubj
# осложнило VERB parataxis
# реализацию NOUN obj
# белорусской ADJ amod
# продукции NOUN nmod
# на ADP case
# российском ADJ amod
# рынке NOUN nmod
# из ADP case
# - ADP case
# за ADP case
# возросшей VERB amod
# конкуренции NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# Мясникович PROPN nsubj
# обратил VERB ROOT
# внимание NOUN obj
# российской ADJ amod
# делегации NOUN nmod
# : PUNCT punct
# наличие NOUN nsubj
# инфраструктуры NOUN nmod
# по ADP case
# созданию NOUN nmod
# совместных ADJ amod
# предприятий NOUN nmod
# способствует VERB parataxis
# решению NOUN iobj
# многих NUM amod
# других ADJ amod
# вопросов NOUN nmod
# . PUNCT punct
# " PUNCT punct
# Поэтому ADV advmod
# у ADP case
# меня PRON ROOT
# такое DET det
# предложение NOUN nsubj
# : PUNCT punct
# давайте VERB parataxis
# строить VERB xcomp
# дальнейшую ADJ amod
# работу NOUN obj
# в ADP case
# основном ADJ nmod
# на ADP case
# том PRON obl
# , PUNCT punct
# чтобы SCONJ mark
# были VERB acl
# совместные ADJ amod
# предприятия NOUN nsubj
# и CCONJ cc
# формировалась VERB conj
# соответствующая ADJ amod
# добавленная ADJ amod
# стоимость NOUN nsubj
# , PUNCT punct
# в ADP case
# этом PRON obl
# интерес NOUN nsubj
# будет AUX cop
# у ADP case
# всех PRON conj
# . PUNCT punct
# И CCONJ cc
# главное ADJ ROOT
# , PUNCT punct
# что SCONJ mark
# мы PRON nsubj
# будем AUX aux
# чувствовать VERB ccomp
# друг PRON obj
# друга PRON fixed
# , PUNCT punct
# какие DET det
# есть VERB fixed
# проблемы NOUN obj
# у ADP case
# каждого DET det
# " PUNCT punct
# , PUNCT punct
# - PUNCT punct
# сказал VERB parataxis
# он PRON nsubj
# . PUNCT punct
# Мясникович PROPN nsubj
# предложил VERB ROOT
# решение NOUN obj
# данного ADJ amod
# вопроса NOUN nmod
# : PUNCT punct
# " PUNCT punct
# Может VERB parataxis
# быть VERB xcomp
# , PUNCT punct
# нам PRON iobj
# стоит VERB parataxis
# создать VERB csubj
# фонд NOUN obj
# , PUNCT punct
# выйти VERB conj
# на ADP case
# создание NOUN obl
# совместной ADJ amod
# инжиниринговой ADJ amod
# компании NOUN nmod
# , PUNCT punct
# то SCONJ mark
# есть VERB fixed
# это PRON nsubj
# будет AUX cop
# юридическое ADJ amod
# лицо NOUN parataxis
# , PUNCT punct
# небольшое ADJ amod
# по ADP case
# численности NOUN obl
# " PUNCT punct
# . PUNCT punct
#
#
#  SPACE dep
# В ADP case
# свою DET det
# очередь NOUN obl
# Толоконский PROPN nsubj
# , PUNCT punct
# как SCONJ mark
# сообщает VERB parataxis
# пресс NOUN nsubj
# - NOUN nsubj
# служба NOUN nsubj
# Совмина PROPN nmod
# Белоруссии PROPN nmod
# , PUNCT punct
# выразил VERB ROOT
# уверенность NOUN obj
# в ADP case
# том PRON nmod
# , PUNCT punct
# что SCONJ mark
# руководители NOUN nsubj
# регионов NOUN nmod
# СФО PROPN nmod
# активно ADV advmod
# подключатся VERB acl
# к ADP case
# выполнению NOUN obl
# поставленных VERB acl
# перед ADP case
# ними PRON obl
# задач NOUN nmod
# , PUNCT punct
# хотя SCONJ mark
# в ADP case
# России PROPN obl
# , PUNCT punct
# как SCONJ case
# и PART advmod
# в ADP case
# Белоруссии PROPN acl
# , PUNCT punct
# и CCONJ cc
# других ADJ amod
# странах NOUN conj
# наблюдается VERB advcl
# экономический ADJ amod
# спад NOUN nsubj:pass
# . PUNCT punct
# Полпред NOUN nsubj
# президента NOUN nmod
# РФ PROPN nmod
# пояснил VERB ROOT
# : PUNCT punct
# " PUNCT punct
# Мы PRON nsubj
# не PART advmod
# потому ADV advmod
# сократили VERB parataxis
# закупки NOUN obj
# белорусской ADJ amod
# техники NOUN nmod
# , PUNCT punct
# что PRON mark
# в ADP case
# чем PRON obl
# - PRON obl
# то PRON obl
# сомневаемся VERB parataxis
# или CCONJ cc
# есть VERB conj
# какие DET det
# - DET det
# то DET det
# другие ADJ amod
# претенденты NOUN nsubj
# на ADP case
# это DET det
# сотрудничество NOUN nmod
# , PUNCT punct
# просто PART advmod
# серьезно ADV advmod
# осложнилась VERB conj
# ситуация NOUN nsubj
# в ADP case
# угольной ADJ amod
# промышленности NOUN nmod
# , PUNCT punct
# произошло VERB conj
# падение NOUN nsubj
# мировых ADJ amod
# экспортных ADJ amod
# цен NOUN nmod
# на ADP case
# сырье NOUN nmod
# " PUNCT punct
# . PUNCT punct
#
#
#  SPACE dep
# Как SCONJ mark
# сообщало VERB parataxis
# ИА PROPN nsubj
# REGNUM PROPN appos
# , PUNCT punct
# 17 ADJ obl
# июня NOUN flat
# в ADP case
# Минске PROPN obl
# Александр PROPN appos
# Лукашенко PROPN flat:name
# во ADP case
# время NOUN fixed
# встречи NOUN obl
# с ADP case
# российской ADJ amod
# делегацией NOUN nmod
# во ADP case
# главе NOUN fixed
# с ADP case
# полномочным ADJ amod
# представителем NOUN obl
# президента NOUN nmod
# России PROPN nmod
# в ADP case
# Сибирском ADJ amod
# федеральном ADJ amod
# округе NOUN nmod
# Виктором PROPN appos
# Толоконским PROPN flat:name
# заявил VERB ROOT
# , PUNCT punct
# что SCONJ mark
# развитие NOUN nsubj
# прямых ADJ amod
# экономических ADJ amod
# связей NOUN nmod
# Белоруссии PROPN nmod
# с ADP case
# российскими ADJ amod
# регионами NOUN nmod
# является VERB ccomp
# основой NOUN xcomp
# успешного ADJ amod
# развития NOUN nmod
# межгосударственных ADJ amod
# интеграционных ADJ amod
# отношений NOUN nmod
# . PUNCT punct
# " PUNCT punct
# Время NOUN nsubj
# сегодня ADV advmod
# такое DET ROOT
# , PUNCT punct
# что SCONJ mark
# весь DET det
# мир NOUN nsubj
# в ADP case
# кризисе NOUN acl:relcl
# . PUNCT punct
# И CCONJ cc
# надеяться VERB csubj
# , PUNCT punct
# уповать VERB conj
# на ADP case
# этот DET det
# мир NOUN obl
# далёкий ADJ obj
# , PUNCT punct
# нам PRON iobj
# нечего VERB ROOT
# , PUNCT punct
# - PUNCT punct
# сказал VERB parataxis
# Лукашенко PROPN nsubj
# , PUNCT punct
# обращаясь VERB advcl
# к ADP case
# делегации NOUN obl
# из ADP case
# Сибири PROPN nmod
# . PUNCT punct
# - PUNCT punct
# У ADP case
# нас PRON obl
# есть VERB ROOT
# опыт NOUN nsubj
# сотрудничества NOUN nmod
# в ADP case
# одном NUM nummod
# государстве NOUN nmod
# . PUNCT punct
# Поэтому ADV advmod
# давайте VERB ROOT
# будем AUX xcomp
# , PUNCT punct
# основываясь VERB advcl
# на ADP case
# нашем DET det
# опыте NOUN obl
# , PUNCT punct
# двигаться VERB xcomp
# вперёд NOUN iobj
# " PUNCT punct
# . PUNCT punct
#
#
#  SPACE dep
# Лукашенко PROPN nsubj
# обратил VERB ROOT
# внимание NOUN obj
# членов NOUN nmod
# российской ADJ amod
# делегации NOUN nmod
# на ADP case
# необходимость NOUN nmod
# наращивания NOUN nmod
# взаимной ADJ amod
# торговли NOUN nmod
# с ADP case
# повышением NOUN nmod
# доли NOUN nmod
# высокотехнологичной ADJ amod
# и CCONJ cc
# наукоемкой ADJ conj
# продукции NOUN nmod
# , PUNCT punct
# а CCONJ cc
# также ADV fixed
# услуг NOUN conj
# . PUNCT punct
# В ADP discourse
# частности NOUN fixed
# , PUNCT punct
# отметил VERB parataxis
# он PRON nsubj
# , PUNCT punct
# строители NOUN nsubj
# из ADP case
# Белоруссии PROPN nmod
# могли VERB ROOT
# бы AUX aux
# привлекаться VERB xcomp
# к ADP case
# реализации NOUN obl
# проектов NOUN nmod
# в ADP case
# Сибири PROPN nmod
# . PUNCT punct
# Он PRON nsubj
# также ADV advmod
# считает VERB ROOT
# , PUNCT punct
# что SCONJ mark
# белорусские ADJ amod
# специалисты NOUN nsubj
# могли VERB ccomp
# бы AUX aux
# участвовать VERB xcomp
# в ADP case
# добыче NOUN obl
# природных ADJ amod
# ресурсов NOUN nmod
# Сибири PROPN nmod
# , PUNCT punct
# работать VERB conj
# в ADP case
# сферах NOUN obl
# сельского ADJ amod
# , PUNCT punct
# коммунального ADJ conj
# и CCONJ cc
# лесного ADJ conj
# хозяйства NOUN nmod
# СФО PROPN nmod
# , PUNCT punct
# участвовать VERB conj
# в ADP case
# совместных ADJ amod
# научно ADJ amod
# - ADJ amod
# технических ADJ amod
# проектах NOUN obl
# . PUNCT punct

# %%
pd.read_csv('collection3/001.ann', delimiter='\t', header=None)
# Out:
#       0            1                 2
# 0    T1      LOC 0 6            Россия
# 1    T2    LOC 50 53               США
# 2    T3    LOC 57 63            Грузию
# 3    T4    LOC 87 93            МОСКВА
# 4    T5  ORG 103 114       РИА Новости
# 5    T6  LOC 116 122            Россия
# 6    T7  LOC 141 144               США
# 7    T8  LOC 161 168           Тбилиси
# 8    T9  LOC 301 307            России
# 9   T10  PER 308 324  Григорий Карасин
# 10  T11  LOC 383 386               США
# 11  T12  PER 387 402   Дэниэлом Фридом
# 12  T13  LOC 505 517      Южной Осетии
# 13  T14  LOC 703 709            Россия
# 14  T15  LOC 723 730           Тбилиси
# 15  T16  LOC 815 825        Вашингтона
# 16  T17  ORG 838 841               МИД
# 17  T18  LOC 842 848            России

# %%
text = data_text.text[0]
navec = Navec.load('navec_news_v1_1B_250K_300d_100q.tar')
ner = NER.load('slovnet_ner_news_v1.tar')
ner.navec(navec)

markup = ner(text)
show_markup(markup.text, markup.spans)
# Out:
# Совмин Белоруссии надеется разгрузить склады в Сибири
# ORG─── LOC───────                              LOC───
# Скопившаяся на складах белорусских предприятий продукция может быть
# реализована в Сибири при помощи административного ресурса российских
#               LOC───
# чиновников. Об этом 17 июня заявил председатель правительства
# Белоруссии Михаил Мясникович на встрече с делегацией Сибирского
# LOC─────── PER──────────────                         LOC────────
# федерального округа России во главе с полномочным представителем
# ─────────────────── LOC───
# президента РФ Виктором Толоконским.
#            LO PER─────────────────
# Во время встречи Мясникович указал на "огромный потенциал"
#                  PER───────
# сотрудничества Белоруссии с Сибирским федеральным округом: по итогам
#                LOC───────   LOC──────────────────────────
# 2012 года взаимный товарооборот составил более $1,4 млрд - на 4,4%
# больше уровня 2011 года. Председатель Совмина Белоруссии с сожалением
#                                       ORG──── LOC───────
# отметил: в I квартале 2013 года объемы поставок снизились на 30%, в
# т.ч. за счёт снижения экспорта белорусских грузовиков и ряда другой
# техники. Мясникович обратился к полномочному представителю президента
#          PER───────
# РФ с просьбой "подтолкнуть" российские компании к активизации закупок
# LO
# белорусской техники, скопившейся на складах Белоруссии, что вызывает
#                                             LOC───────
# целый ряд проблем для руководства республики.
# Напомним, 11 июня на совещании по вопросам развития промышленного
# комплекса и реализации белорусской продукции в Администрации
#                                                ORG───────────
# президента Белоруссии Александр Лукашенко подверг резкой критике
# ────────── LOC─────── PER────────────────
# состояние дел в белорусской экономике. Он в очередной раз распорядился
#  в течение лета "разгрузить склады" предприятий республики, не приняв
# ссылки чиновников на вступление России в ВТО, что осложнило реализацию
#                                 LOC───   ORG
#  белорусской продукции на российском рынке из-за возросшей
# конкуренции.
# Мясникович обратил внимание российской делегации: наличие
# PER───────
# инфраструктуры по созданию совместных предприятий способствует решению
#  многих других вопросов. "Поэтому у меня такое предложение: давайте
# строить дальнейшую работу в основном на том, чтобы были совместные
# предприятия и формировалась соответствующая добавленная стоимость, в
# этом интерес будет у всех. И главное, что мы будем чувствовать друг
# друга, какие есть проблемы у каждого", - сказал он. Мясникович
#                                                     PER───────
# предложил решение данного вопроса: "Может быть, нам стоит создать
# фонд, выйти на создание совместной инжиниринговой компании, то есть
# это будет юридическое лицо, небольшое по численности".
# В свою очередь Толоконский, как сообщает пресс-служба Совмина
#                PER────────                            ORG────
# Белоруссии, выразил уверенность в том, что руководители регионов СФО
# LOC───────                                                       LOC
# активно подключатся к выполнению поставленных перед ними задач, хотя в
#  России, как и в Белоруссии, и других странах наблюдается
#  LOC───          LOC───────
# экономический спад. Полпред президента РФ пояснил: "Мы не потому
#                                        LO
# сократили закупки белорусской техники, что в чем-то сомневаемся или
# есть какие-то другие претенденты на это сотрудничество, просто
# серьезно осложнилась ситуация в угольной промышленности, произошло
# падение мировых экспортных цен на сырье".
# Как сообщало ИА REGNUM, 17 июня в Минске Александр Лукашенко во время
#              ORG──────            LOC─── PER────────────────
# встречи с российской делегацией во главе с полномочным представителем
# президента России в Сибирском федеральном округе Виктором Толоконским
#            LOC───   LOC───────────────────────── PER─────────────────
# заявил, что развитие прямых экономических связей Белоруссии с
#                                                  LOC───────
# российскими регионами является основой успешного развития
# межгосударственных интеграционных отношений. "Время сегодня такое, что
#  весь мир в кризисе. И надеяться, уповать на этот мир далёкий, нам
# нечего, - сказал Лукашенко, обращаясь к делегации из Сибири. - У нас
#                  PER──────                           LOC───
# есть опыт сотрудничества в одном государстве. Поэтому давайте будем,
# основываясь на нашем опыте, двигаться вперёд".
# Лукашенко обратил внимание членов российской делегации на
# PER──────
# необходимость наращивания взаимной торговли с повышением доли
# высокотехнологичной и наукоемкой продукции, а также услуг. В
# частности, отметил он, строители из Белоруссии могли бы привлекаться к
#                                     LOC───────
#  реализации проектов в Сибири. Он также считает, что белорусские
#                        LOC───
# специалисты могли бы участвовать в добыче природных ресурсов Сибири,
#                                                              LOC───
# работать в сферах сельского, коммунального и лесного хозяйства СФО,
#                                                                LOC
# участвовать в совместных научно-технических проектах.

# %%
fileDir = r"collection3"
fileExt = r".ann"
documents_ann = [_ for _ in os.listdir(fileDir) if _.endswith(fileExt)]
print(documents_ann)
# Out:
# ['356.ann', '149.ann', '368.ann', '183.ann', '252.ann', '094.ann', '100.ann', '537.ann', '409.ann', '130.ann', '623.ann', 'last_21.ann', '428.ann', '251.ann', '434.ann', '375.ann', '483.ann', '328.ann', '171.ann', '357.ann', 'artjakov.ann', '091.ann', '445.ann', '514.ann', '14_01_13i.ann', '279.ann', '058.ann', '374.ann', '299.ann', '042.ann', '243.ann', '263.ann', '431.ann', '310.ann', '362.ann', '25_12_12a.ann', '032.ann', '316.ann', '399.ann', '288.ann', '324.ann', '063.ann', '493.ann', '270.ann', '439.ann', '22_11_12d.ann', '192.ann', '170.ann', '118.ann', '446.ann', '506.ann', '309.ann', '23_11_12b.ann', '191.ann', '072.ann', '045.ann', '449.ann', '575.ann', '109.ann', '093.ann', '21_11_12c.ann', '20_11_12i.ann', '244.ann', '410.ann', '412.ann', '326.ann', '461.ann', '014.ann', '343.ann', '10_01_13a.ann', '146.ann', '377.ann', '038.ann', '09_01_13c.ann', '532.ann', '281.ann', '119.ann', '061.ann', '067.ann', '029.ann', '459.ann', 'chaves.ann', '286.ann', '289.ann', '240.ann', '233.ann', '197.ann', '103.ann', '553.ann', '20_11_12d.ann', '22_11_12g.ann', '366.ann', '048.ann', '379.ann', '04_12_12d.ann', '548.ann', '336.ann', '427.ann', '330.ann', '229.ann', '04_12_12g.ann', '180.ann', '421.ann', '515.ann', '23_11_12a.ann', '443.ann', '378.ann', '221.ann', '120.ann', '520.ann', '09_01_13i.ann', '074.ann', '115.ann', '142.ann', '213.ann', '110.ann', '405.ann', '1146.ann', '358.ann', '2006.ann', '287.ann', '385.ann', '112.ann', '466.ann', '554.ann', '455.ann', '342.ann', '332.ann', '390.ann', '383.ann', '117.ann', '567.ann', '565.ann', '339.ann', '540.ann', '069.ann', '26_11_12c.ann', 'last_53.ann', '476.ann', '131.ann', '211.ann', '070.ann', '562.ann', '138.ann', '129.ann', '236.ann', '381.ann', '454.ann', 'last_17.ann', '218.ann', '452.ann', '122.ann', '11_01_13e.ann', '344.ann', '346.ann', '387.ann', '533 (!).ann', '504.ann', '508.ann', '261.ann', '010.ann', '294.ann', 'last_12.ann', '361.ann', '579.ann', '376.ann', '561.ann', '009.ann', '426.ann', '593.ann', '462.ann', '528.ann', '276.ann', '285.ann', '392.ann', '176.ann', '151.ann', '519.ann', '545.ann', '413.ann', '174.ann', '360.ann', '28_11_12g.ann', '148.ann', '136.ann', '574.ann', '052.ann', '082.ann', '1050.ann', '080.ann', '280.ann', '477.ann', '071.ann', '488.ann', '113.ann', '597.ann', '09_01_13h.ann', '068.ann', '432.ann', '472.ann', '282.ann', '518.ann', '322.ann', '327.ann', '22_11_12i.ann', '020.ann', 'chirkunov.ann', '167.ann', '600.ann', '137.ann', '027.ann', '501.ann', '15_01_13e.ann', 'last_15.ann', '092.ann', 'last_18.ann', '277.ann', '14_01_13c.ann', '200.ann', '353.ann', '594.ann', '599.ann', '364.ann', '2004.ann', '522.ann', '513.ann', '164.ann', '407.ann', '458.ann', '097.ann', '262.ann', 'last_16.ann', '247.ann', '444.ann', '222.ann', '331.ann', '345.ann', '04_12_12h_corr.ann', '096.ann', 'last_01.ann', '017.ann', '040.ann', '359.ann', '480.ann', '182.ann', '223.ann', '329.ann', '491.ann', '386.ann', '589.ann', '535.ann', '347.ann', '502.ann', '323.ann', '139.ann', '015 (!).ann', '023.ann', '150.ann', '046.ann', '497.ann', '598 (!).ann', '591.ann', '1147.ann', '10_01_13i.ann', '274.ann', '089.ann', '2010.ann', '049.ann', '266.ann', '189.ann', 'last_09.ann', '269.ann', '203.ann', '28_11_12h.ann', '524.ann', '568.ann', '264.ann', '081.ann', '503.ann', '04_02_13a_abdulatipov.ann', '193.ann', '318.ann', '350.ann', '217.ann', '435.ann', '09_01_13d.ann', '047.ann', '011.ann', '21_11_12h.ann', '546.ann', '10_01_13d.ann', '505.ann', '156.ann', '178.ann', '496.ann', '400.ann', '632.ann', '463.ann', '471.ann', '179.ann', '355.ann', '185.ann', '257.ann', '370.ann', '490.ann', '28_11_12f.ann', '267.ann', '437.ann', '408.ann', '19_11_12h.ann', '425.ann', '201.ann', '499.ann', '157.ann', '04_12_12b.ann', '09_01_13a.ann', '036.ann', '265.ann', '516.ann', '239.ann', '143.ann', '393.ann', '420.ann', '234.ann', '173.ann', '188.ann', '03_12_12h.ann', '578.ann', '088.ann', '507.ann', '25_12_12d.ann', '531.ann', '28_11_12j.ann', '125.ann', '043.ann', '542.ann', '313.ann ...

# %%
ann = pd.read_csv('collection3/001.ann', delimiter='\t', header=None)
ann
# Out:
#       0            1                 2
# 0    T1      LOC 0 6            Россия
# 1    T2    LOC 50 53               США
# 2    T3    LOC 57 63            Грузию
# 3    T4    LOC 87 93            МОСКВА
# 4    T5  ORG 103 114       РИА Новости
# 5    T6  LOC 116 122            Россия
# 6    T7  LOC 141 144               США
# 7    T8  LOC 161 168           Тбилиси
# 8    T9  LOC 301 307            России
# 9   T10  PER 308 324  Григорий Карасин
# 10  T11  LOC 383 386               США
# 11  T12  PER 387 402   Дэниэлом Фридом
# 12  T13  LOC 505 517      Южной Осетии
# 13  T14  LOC 703 709            Россия
# 14  T15  LOC 723 730           Тбилиси
# 15  T16  LOC 815 825        Вашингтона
# 16  T17  ORG 838 841               МИД
# 17  T18  LOC 842 848            России

# %%
docs = []
# print(len(data_text))
# print(len(documents_ann))
# for i in range(len(data_text)):
for i in range(len(documents_ann)):
    words = []
    labels = []
    text = data_text['text'][i]
    # print(documents_ann[i])
    df = pd.read_csv('Collection3/' + documents_ann[i], delimiter='\t', header=None, quoting=csv.QUOTE_NONE, encoding='utf-8')
    df_ann = pd.DataFrame()
    df_ann['Token'] = df.loc[:, 2]
    split_1 = [loc.split() for loc in df.loc[:, 1].values]
    df_ann['Entity'] = [loc[0] for loc in split_1]
       
    dic = {}
    for j in range(len(df)):
        token = df_ann['Token'][j].lower().split()
        entity = df_ann['Entity'][j]
        for tok in token:
            dic[tok] = entity

    for token in tokenize(text):
        if (token.text.lower() in dic.keys()):
            words.append(token.text)
            labels.append(dic[token.text.lower()])
        else:
            words.append(token.text)
            labels.append('OUT')
    
    docs.append([words, labels])

# %%
print(docs[0][0]), print(docs[0][1])
# Out:
# ['Совмин', 'Белоруссии', 'надеется', 'разгрузить', 'склады', 'в', 'Сибири', 'Скопившаяся', 'на', 'складах', 'белорусских', 'предприятий', 'продукция', 'может', 'быть', 'реализована', 'в', 'Сибири', 'при', 'помощи', 'административного', 'ресурса', 'российских', 'чиновников', '.', 'Об', 'этом', '17', 'июня', 'заявил', 'председатель', 'правительства', 'Белоруссии', 'Михаил', 'Мясникович', 'на', 'встрече', 'с', 'делегацией', 'Сибирского', 'федерального', 'округа', 'России', 'во', 'главе', 'с', 'полномочным', 'представителем', 'президента', 'РФ', 'Виктором', 'Толоконским', '.', 'Во', 'время', 'встречи', 'Мясникович', 'указал', 'на', '"', 'огромный', 'потенциал', '"', 'сотрудничества', 'Белоруссии', 'с', 'Сибирским', 'федеральным', 'округом', ':', 'по', 'итогам', '2012', 'года', 'взаимный', 'товарооборот', 'составил', 'более', '$', '1,4', 'млрд', '-', 'на', '4,4', '%', 'больше', 'уровня', '2011', 'года', '.', 'Председатель', 'Совмина', 'Белоруссии', 'с', 'сожалением', 'отметил', ':', 'в', 'I', 'квартале', '2013', 'года', 'объемы', 'поставок', 'снизились', 'на', '30', '%', ',', 'в', 'т', '.', 'ч', '.', 'за', 'счёт', 'снижения', 'экспорта', 'белорусских', 'грузовиков', 'и', 'ряда', 'другой', 'техники', '.', 'Мясникович', 'обратился', 'к', 'полномочному', 'представителю', 'президента', 'РФ', 'с', 'просьбой', '"', 'подтолкнуть', '"', 'российские', 'компании', 'к', 'активизации', 'закупок', 'белорусской', 'техники', ',', 'скопившейся', 'на', 'складах', 'Белоруссии', ',', 'что', 'вызывает', 'целый', 'ряд', 'проблем', 'для', 'руководства', 'республики', '.', 'Напомним', ',', '11', 'июня', 'на', 'совещании', 'по', 'вопросам', 'развития', 'промышленного', 'комплекса', 'и', 'реализации', 'белорусской', 'продукции', 'в', 'Администрации', 'президента', 'Белоруссии', 'Александр', 'Лукашенко', 'подверг', 'резкой', 'критике', 'состояние', 'дел', 'в', 'белорусской', 'экономике', '.', 'Он', 'в', 'очередной', 'раз', 'распорядился', 'в', 'течение', 'лета', '"', 'разгрузить', 'склады', '"', 'предприятий', 'республики', ',', 'не', 'приняв', 'ссылки', 'чиновников', 'на', 'вступление', 'России', 'в', 'ВТО', ',', 'что', 'осложнило', 'реализацию', 'белорусской', 'продукции', 'на', 'российском', 'рынке', 'из-за', 'возросшей', 'конкуренции', '.', 'Мясникович', 'обратил', 'внимание', 'российской', 'делегации', ':', 'наличие', 'инфраструктуры', 'по', 'созданию', 'совместных', 'предприятий', 'способствует', 'решению', 'многих', 'других', 'вопросов', '.', '"', 'Поэтому', 'у', 'меня', 'такое', 'предложение', ':', 'давайте', 'строить', 'дальнейшую', 'работу', 'в', 'основном', 'на', 'том', ',', 'чтобы', 'были', 'совместные', 'предприятия', 'и', 'формировалась', 'соответствующая', 'добавленная', 'стоимость', ',', 'в', 'этом', 'интерес', 'будет', 'у', 'всех', '.', 'И', 'главное', ',', 'что', 'мы', 'будем', 'чувствовать', 'друг', 'друга', ',', 'какие', 'есть', 'проблемы', 'у', 'каждого', '"', ',', '-', 'сказал', 'он', '.', 'Мясникович', 'предложил', 'решение', 'данного', 'вопроса', ':', '"', 'Может', 'быть', ',', 'нам', 'стоит', 'создать', 'фонд', ',', 'выйти', 'на', 'создание', 'совместной', 'инжиниринговой', 'компании', ',', 'то', 'есть', 'это', 'будет', 'юридическое', 'лицо', ',', 'небольшое', 'по', 'численности', '"', '.', 'В', 'свою', 'очередь', 'Толоконский', ',', 'как', 'сообщает', 'пресс-служба', 'Совмина', 'Белоруссии', ',', 'выразил', 'уверенность', 'в', 'том', ',', 'что', 'руководители', 'регионов', 'СФО', 'активно', 'подключатся', 'к', 'выполнению', 'поставленных', 'перед', 'ними', 'задач', ',', 'хотя', 'в', 'России', ',', 'как', 'и', 'в', 'Белоруссии', ',', 'и', 'других', 'странах', 'наблюдается', 'экономический', 'спад', '.', 'Полпред', 'президента', 'РФ', 'пояснил', ':', '"', 'Мы', 'не', 'потому', 'сократили', 'закупки', 'белорусской', 'техники', ',', 'что', 'в', 'чем-то', 'сомневаемся', 'или', 'есть', 'какие-то', 'другие', 'претенденты', 'на', 'это', 'сотрудничество', ',', 'просто', 'серьезно', 'осложнилась', 'ситуация', 'в', 'угольной', 'промышленности ...
# ['OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'OUT', 'O ...
# (None, None)

# %%
data, labels = list(zip(*docs))
for w, e in zip(data[0], labels[0]):
    print(f'{w}\t{e}')
# Out:
# Совмин	OUT
# Белоруссии	OUT
# надеется	OUT
# разгрузить	OUT
# склады	OUT
# в	OUT
# Сибири	OUT
# Скопившаяся	OUT
# на	OUT
# складах	OUT
# белорусских	OUT
# предприятий	OUT
# продукция	OUT
# может	OUT
# быть	OUT
# реализована	OUT
# в	OUT
# Сибири	OUT
# при	OUT
# помощи	OUT
# административного	OUT
# ресурса	OUT
# российских	OUT
# чиновников	OUT
# .	OUT
# Об	OUT
# этом	OUT
# 17	OUT
# июня	OUT
# заявил	OUT
# председатель	OUT
# правительства	OUT
# Белоруссии	OUT
# Михаил	OUT
# Мясникович	OUT
# на	OUT
# встрече	OUT
# с	OUT
# делегацией	OUT
# Сибирского	OUT
# федерального	OUT
# округа	OUT
# России	OUT
# во	OUT
# главе	OUT
# с	OUT
# полномочным	OUT
# представителем	OUT
# президента	OUT
# РФ	OUT
# Виктором	OUT
# Толоконским	OUT
# .	OUT
# Во	OUT
# время	OUT
# встречи	OUT
# Мясникович	OUT
# указал	OUT
# на	OUT
# "	OUT
# огромный	OUT
# потенциал	OUT
# "	OUT
# сотрудничества	OUT
# Белоруссии	OUT
# с	OUT
# Сибирским	OUT
# федеральным	OUT
# округом	OUT
# :	OUT
# по	OUT
# итогам	OUT
# 2012	OUT
# года	OUT
# взаимный	OUT
# товарооборот	OUT
# составил	OUT
# более	OUT
# $	OUT
# 1,4	OUT
# млрд	OUT
# -	OUT
# на	OUT
# 4,4	OUT
# %	OUT
# больше	OUT
# уровня	OUT
# 2011	OUT
# года	OUT
# .	OUT
# Председатель	OUT
# Совмина	OUT
# Белоруссии	OUT
# с	OUT
# сожалением	OUT
# отметил	OUT
# :	OUT
# в	OUT
# I	OUT
# квартале	OUT
# 2013	OUT
# года	OUT
# объемы	OUT
# поставок	OUT
# снизились	OUT
# на	OUT
# 30	OUT
# %	OUT
# ,	OUT
# в	OUT
# т	OUT
# .	OUT
# ч	OUT
# .	OUT
# за	OUT
# счёт	OUT
# снижения	OUT
# экспорта	OUT
# белорусских	OUT
# грузовиков	OUT
# и	OUT
# ряда	OUT
# другой	OUT
# техники	OUT
# .	OUT
# Мясникович	OUT
# обратился	OUT
# к	OUT
# полномочному	OUT
# представителю	OUT
# президента	OUT
# РФ	OUT
# с	OUT
# просьбой	OUT
# "	OUT
# подтолкнуть	OUT
# "	OUT
# российские	OUT
# компании	OUT
# к	OUT
# активизации	OUT
# закупок	OUT
# белорусской	OUT
# техники	OUT
# ,	OUT
# скопившейся	OUT
# на	OUT
# складах	OUT
# Белоруссии	OUT
# ,	OUT
# что	OUT
# вызывает	OUT
# целый	OUT
# ряд	OUT
# проблем	OUT
# для	OUT
# руководства	OUT
# республики	OUT
# .	OUT
# Напомним	OUT
# ,	OUT
# 11	OUT
# июня	OUT
# на	OUT
# совещании	OUT
# по	OUT
# вопросам	OUT
# развития	OUT
# промышленного	OUT
# комплекса	OUT
# и	OUT
# реализации	OUT
# белорусской	OUT
# продукции	OUT
# в	OUT
# Администрации	OUT
# президента	OUT
# Белоруссии	OUT
# Александр	OUT
# Лукашенко	OUT
# подверг	OUT
# резкой	OUT
# критике	OUT
# состояние	OUT
# дел	OUT
# в	OUT
# белорусской	OUT
# экономике	OUT
# .	OUT
# Он	OUT
# в	OUT
# очередной	OUT
# раз	OUT
# распорядился	OUT
# в	OUT
# течение	OUT
# лета	OUT
# "	OUT
# разгрузить	OUT
# склады	OUT
# "	OUT
# предприятий	OUT
# республики	OUT
# ,	OUT
# не	OUT
# приняв	OUT
# ссылки	OUT
# чиновников	OUT
# на	OUT
# вступление	OUT
# России	OUT
# в	OUT
# ВТО	OUT
# ,	OUT
# что	OUT
# осложнило	OUT
# реализацию	OUT
# белорусской	OUT
# продукции	OUT
# на	OUT
# российском	OUT
# рынке	OUT
# из-за	OUT
# возросшей	OUT
# конкуренции	OUT
# .	OUT
# Мясникович	OUT
# обратил	OUT
# внимание	OUT
# российской	OUT
# делегации	OUT
# :	OUT
# наличие	OUT
# инфраструктуры	OUT
# по	OUT
# созданию	OUT
# совместных	OUT
# предприятий	OUT
# способствует	OUT
# решению	OUT
# многих	OUT
# других	OUT
# вопросов	OUT
# .	OUT
# "	OUT
# Поэтому	OUT
# у	OUT
# меня	OUT
# такое	OUT
# предложение	OUT
# :	OUT
# давайте	OUT
# строить	OUT
# дальнейшую	OUT
# работу	OUT
# в	OUT
# основном	OUT
# на	OUT
# том	OUT
# ,	OUT
# чтобы	OUT
# были	OUT
# совместные	OUT
# предприятия	OUT
# и	OUT
# формировалась	OUT
# соответствующая	OUT
# добавленная	OUT
# стоимость	OUT
# ,	OUT
# в	OUT
# этом	OUT
# интерес	OUT
# будет	OUT
# у	OUT
# всех	OUT
# .	OUT
# И	OUT
# главное	OUT
# ,	OUT
# что	OUT
# мы	OUT
# будем	OUT
# чувствовать	OUT
# друг	OUT
# друга	OUT
# ,	OUT
# какие	OUT
# есть	OUT
# проблемы	OUT
# у	OUT
# каждого	OUT
# "	OUT
# ,	OUT
# -	OUT
# сказал	OUT
# он	OUT
# .	OUT
# Мясникович	OUT
# предложил	OUT
# решение	OUT
# данного	OUT
# вопроса	OUT
# :	OUT
# "	OUT
# Может	OUT
# быть	OUT
# ,	OUT
# нам	OUT
# стоит	OUT
# создать	OUT
# фонд	OUT
# ,	OUT
# выйти	OUT
# на	OUT
# создание	OUT
# совместной	OUT
# инжиниринговой	OUT
# компании	OUT
# ,	OUT
# то	OUT
# есть	OUT
# это	OUT
# будет	OUT
# юридическое	OUT
# лицо	OUT
# ,	OUT
# небольшое	OUT
# по	OUT
# численности	OUT
# "	OUT
# .	OUT
# В	OUT
# свою	OUT
# очередь	OUT
# Толоконский	OUT
# ,	OUT
# как	OUT
# сообщает	OUT
# пресс-служба	OUT
# Совмина	OUT
# Белоруссии	OUT
# ,	OUT
# выразил	OUT
# уверенность	OUT
# в	OUT
# том	OUT
# ,	OUT
# что	OUT
# руководители	OUT
# регионов	OUT
# СФО	OUT
# активно	OUT
# подключатся	OUT
# к	OUT
# выполнению	OUT
# поставленных	OUT
# перед	OUT
# ними	OUT
# задач	OUT
# ,	OUT
# хотя	OUT
# в	OUT
# России	OUT
# ,	OUT
# как	OUT
# и	OUT
# в	OUT
# Белоруссии	OUT
# ,	OUT
# и	OUT
# других	OUT
# странах	OUT
# наблюдается	OUT
# экономический	OUT
# спад	OUT
# .	OUT
# Полпред	OUT
# президента	OUT
# РФ	OUT
# пояснил	OUT
# :	OUT
# "	OUT
# Мы	OUT
# не	OUT
# потому	OUT
# сократили	OUT
# закупки	OUT
# белорусской	OUT
# техники	OUT
# ,	OUT
# что	OUT
# в	OUT
# чем-то	OUT
# сомневаемся	OUT
# или	OUT
# есть	OUT
# какие-то	OUT
# другие	OUT
# претенденты	OUT
# на	OUT
# это	OUT
# сотрудничество	OUT
# ,	OUT
# просто	OUT
# серьезно	OUT
# осложнилась	OUT
# ситуация	OUT
# в	OUT
# угольной	OUT
# промышленности	OUT
# ,	OUT
# произошло	OUT
# падение	OUT
# мировых	OUT
# экспортных	OUT
# цен	OUT
# на	OUT
# сырье	OUT
# "	OUT
# .	OUT
# Как	OUT
# сообщало	OUT
# ИА	OUT
# REGNUM	OUT
# ,	OUT
# 17	OUT
# июня	OUT
# в	OUT
# Минске	OUT
# Александр	OUT
# Лукашенко	OUT
# во	OUT
# время	OUT
# встречи	OUT
# с	OUT
# российской	OUT
# делегацией	OUT
# во	OUT
# главе	OUT
# с	OUT
# полномочным	OUT
# представителем	OUT
# президента	OUT
# России	OUT
# в	OUT
# Сибирском	OUT
# федеральном	OUT
# округе	OUT
# Виктором	OUT
# Толоконским	OUT
# заявил	OUT
# ,	OUT
# что	OUT
# развитие	OUT
# прямых	OUT
# экономических	OUT
# связей	OUT
# Белоруссии	OUT
# с	OUT
# российскими	OUT
# регионами	OUT
# является	OUT
# основой	OUT
# успешного	OUT
# развития	OUT
# межгосударственных	OUT
# интеграционных	OUT
# отношений	OUT
# .	OUT
# "	OUT
# Время	OUT
# сегодня	OUT
# такое	OUT
# ,	OUT
# что	OUT
# весь	OUT
# мир	OUT
# в	OUT
# кризисе	OUT
# .	OUT
# И	OUT
# надеяться	OUT
# ,	OUT
# уповать	OUT
# на	OUT
# этот	OUT
# мир	OUT
# далёкий	OUT
# ,	OUT
# нам	OUT
# нечего	OUT
# ,	OUT
# -	OUT
# сказал	OUT
# Лукашенко	OUT
# ,	OUT
# обращаясь	OUT
# к	OUT
# делегации	OUT
# из	OUT
# Сибири	OUT
# .	OUT
# -	OUT
# У	OUT
# нас	OUT
# есть	OUT
# опыт	OUT
# сотрудничества	OUT
# в	OUT
# одном	OUT
# государстве	OUT
# .	OUT
# Поэтому	OUT
# давайте	OUT
# будем	OUT
# ,	OUT
# основываясь	OUT
# на	OUT
# нашем	OUT
# опыте	OUT
# ,	OUT
# двигаться	OUT
# вперёд	OUT
# "	OUT
# .	OUT
# Лукашенко	OUT
# обратил	OUT
# внимание	OUT
# членов	OUT
# российской	OUT
# делегации	OUT
# на	OUT
# необходимость	OUT
# наращивания	OUT
# взаимной	OUT
# торговли	OUT
# с	OUT
# повышением	OUT
# доли	OUT
# высокотехнологичной	OUT
# и	OUT
# наукоемкой	OUT
# продукции	OUT
# ,	OUT
# а	OUT
# также	OUT
# услуг	OUT
# .	OUT
# В	OUT
# частности	OUT
# ,	OUT
# отметил	OUT
# он	OUT
# ,	OUT
# строители	OUT
# из	OUT
# Белоруссии	OUT
# могли	OUT
# бы	OUT
# привлекаться	OUT
# к	OUT
# реализации	OUT
# проектов	OUT
# в	OUT
# Сибири	OUT
# .	OUT
# Он	OUT
# также	OUT
# считает	OUT
# ,	OUT
# что	OUT
# белорусские	OUT
# специалисты	OUT
# могли	OUT
# бы	OUT
# участвовать	OUT
# в	OUT
# добыче	OUT
# природных	OUT
# ресурсов	OUT
# Сибири	OUT
# ,	OUT
# работать	OUT
# в	OUT
# сферах	OUT
# сельского	OUT
# ,	OUT
# коммунального	OUT
# и	OUT
# лесного	OUT
# хозяйства	OUT
# СФО	OUT
# ,	OUT
# участвовать	OUT
# в	OUT
# совместных	OUT
# научно-технических	OUT
# проектах	OUT
# .	OUT

# %%
df = pd.DataFrame({'sent_id': [i for j in [[i] * len(s) for i, s in enumerate(data)] for i in j],
                   'data': [i for j in data for i in j],
                   'entities': [i for j in labels for i in j]})
df.head(50)
# Out:
#     sent_id               data entities
# 0         0             Совмин      OUT
# 1         0         Белоруссии      OUT
# 2         0           надеется      OUT
# 3         0         разгрузить      OUT
# 4         0             склады      OUT
# 5         0                  в      OUT
# 6         0             Сибири      OUT
# 7         0        Скопившаяся      OUT
# 8         0                 на      OUT
# 9         0            складах      OUT
# 10        0        белорусских      OUT
# 11        0        предприятий      OUT
# 12        0          продукция      OUT
# 13        0              может      OUT
# 14        0               быть      OUT
# 15        0        реализована      OUT
# 16        0                  в      OUT
# 17        0             Сибири      OUT
# 18        0                при      OUT
# 19        0             помощи      OUT
# 20        0  административного      OUT
# 21        0            ресурса      OUT
# 22        0         российских      OUT
# 23        0         чиновников      OUT
# 24        0                  .      OUT
# 25        0                 Об      OUT
# 26        0               этом      OUT
# 27        0                 17      OUT
# 28        0               июня      OUT
# 29        0             заявил      OUT
# 30        0       председатель      OUT
# 31        0      правительства      OUT
# 32        0         Белоруссии      OUT
# 33        0             Михаил      OUT
# 34        0         Мясникович      OUT
# 35        0                 на      OUT
# 36        0            встрече      OUT
# 37        0                  с      OUT
# 38        0         делегацией      OUT
# 39        0         Сибирского      OUT
# 40        0       федерального      OUT
# 41        0             округа      OUT
# 42        0             России      OUT
# 43        0                 во      OUT
# 44        0              главе      OUT
# 45        0                  с      OUT
# 46        0        полномочным      OUT
# 47        0     представителем      OUT
# 48        0         президента      OUT
# 49        0                 РФ      OUT

# %%
class SentenceGetter(object):
    
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, t) for w, t in zip(s['data'].values.tolist(), 
                                                           s['entities'].values.tolist())]
        self.grouped = self.data.groupby('sent_id').apply(agg_func)
        self.sentences = [s for s in self.grouped]
        
    def get_next(self):
        try: 
            s = self.grouped['Sentence: {}'.format(self.n_sent)]
            self.n_sent += 1
            return s 
        except:
            return None

getter = SentenceGetter(df)

sentences = getter.sentences

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]
    
    features = {
        'bias': 1.0, 
        'word.lower()': word.lower(), 
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isdigit()': word.isdigit()
    }
    if i > 0:
        word1 = sent[i - 1][0]
        features.update({
            '-1:word.lower()': word1.lower()
        })
    else:
        features['BOS'] = True
    if i < len(sent) - 1:
        word1 = sent[i + 1][0]
        features.update({
            '+1:word.lower()': word1.lower()
        })
    else:
        features['EOS'] = True

    return features

def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, label in sent]

def sent2tokens(sent):
    return [token for token, label in sent]

# %%
X = [sent2features(s) for s in sentences]
y = [sent2labels(s) for s in sentences]

# %%
X = [sent2features(s) for s in sentences]
y = [sent2labels(s) for s in sentences]
X[2][7]
# Out:
# {'bias': 1.0,
#  'word.lower()': 'на',
#  'word[-3:]': 'на',
#  'word[-2:]': 'на',
#  'word.isdigit()': False,
#  '-1:word.lower()': 'еще',
#  '+1:word.lower()': '15'}

# %%
len(X)
# Out:
# 713

# %%
X_train = X[:700]
X_test = X[700:]
y_train = y[:700]
y_test = y[700:]

# %%
# %%time

crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs', # Градиентный спуск с использованием метода L-BFGS
    c1=0.1, # Коэффициент для регуляризации L1
    c2=0.1, # Коэффициент для регуляризации L2
    max_iterations=1000, # Максимальное количество итераций
    all_possible_transitions=True, # Генерация объектов (не встречающихся в обучающих данных)
    verbose=False # Выключение режима тренировки
)

try:
    crf.fit(X_train, y_train)
except AttributeError:
    pass
# Out:
# CPU times: user 28 s, sys: 89 ms, total: 28.1 s
# Wall time: 29.3 s

# %%
all_entities = sorted(df.entities.unique().tolist())
len(all_entities)
# Out:
# 4

# %%
y_pred = crf.predict(X_test)
metrics.flat_f1_score(y_test, y_pred, average='weighted', labels=all_entities)
# Out:
# 0.9853420963702066

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]
    
    features = {
        'bias': 1.0, 
        'word.lower()': word.lower(), 
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isdigit()': word.isdigit()
    }
    return features

def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, label in sent]

def sent2tokens(sent):
    return [token for token, label in sent]

# %%
X = [sent2features(s) for s in sentences]
y = [sent2labels(s) for s in sentences]
X[1][7]
# Out:
# {'bias': 1.0,
#  'word.lower()': 'путина',
#  'word[-3:]': 'ина',
#  'word[-2:]': 'на',
#  'word.isdigit()': False}

# %%
len(X)
# Out:
# 713

# %%
X_train = X[:700]
X_test = X[700:]
y_train = y[:700]
y_test = y[700:]

# %%
# %%time

crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=1000,
    all_possible_transitions=True,
    verbose=False
)

try:
    crf.fit(X_train, y_train)
except AttributeError:
    pass
# Out:
# CPU times: user 32.9 s, sys: 101 ms, total: 33 s
# Wall time: 33.3 s

# %%
all_entities = sorted(df.entities.unique().tolist())
len(all_entities)
# Out:
# 4

# %%
y_pred = crf.predict(X_test)
metrics.flat_f1_score(y_test, y_pred, average='weighted', labels=all_entities)
# Out:
# 0.9855229392577891
