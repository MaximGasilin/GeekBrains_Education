# %% [markdown]
# # Генератор (болталка)

# %% [markdown]
# Медицинскую вопросно-ответную систему, датасет https://huggingface.co/datasets/blinoff/medical_qa_ru_data.

# %% [markdown]
# Для реализации подключения к ChatGPT использовал следующую статью на ХАБРе:https://habr.com/ru/post/704600/

# %% [markdown]
# Информация о получении api для чат-бота использовал статью: https://habr.com/ru/post/442800/

# %%
# !pip3 install transformers torch wikipedia torchvision torchaudio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 37.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 17.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 82.4 MB/s eta 0:00:00
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11695 sha256=422523b4dad4c510d6d132cb24fdccc1408abc44acf64820903dd2fda6d7abd2
#   Stored in directory: /root/.cache/pip/wheels/07/93/05/72c05349177dca2e0ba31a33ba4f7907606f7ddef303517c6a
# Successfully built wikipedia
# ...

# %%
# !pip3 install torch==1.12.1 torchvision==0.13.1 torchaudio==0.12.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 32.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 59.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu116
#     Uninstalling torch-1.13.1+cu116:
#       Successfully uninstalled torch-1.13.1+cu116
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.1+cu116
#     Uninstalling torchvision-0.14.1+cu116:
#       Successfully uninstalled torchvision-0.14.1+cu116
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.13.1+cu116
#     Uninstalling torchaudio-0.13.1+cu116:
#       Successfully uninstalled torchaudio-0.13.1+cu116
# ...

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch
#DEVICE = torch.device("cuda:0")

model_name_or_path = "radm/rugpt3medium-tathagata"
model_name_or_path = "sberbank-ai/rugpt3medium_based_on_gpt2"
tokenizer = GPT2Tokenizer.from_pretrained("sberbank-ai/rugpt3medium_based_on_gpt2")
model = GPT2LMHeadModel.from_pretrained(model_name_or_path)#.to(DEVICE)

# %%
def respond_to_dialog(texts):
    prefix = '\nx:'
    for i, t in enumerate(texts):
        prefix += t
        prefix += '\nx:' if i % 2 == 1 else '\ny:'
    tokens = tokenizer(prefix, return_tensors='pt')
    tokens = {k: v.to(model.device) for k, v in tokens.items()}
    end_token_id = tokenizer.encode('\n')[0]
    size = tokens['input_ids'].shape[1]
    output = model.generate(
        **tokens, 
        eos_token_id=end_token_id,
        do_sample=True, 
        max_length=size+128, 
        repetition_penalty=3.2, 
        temperature=1,
        num_beams=3,
        length_penalty=0.01,
        pad_token_id=end_token_id
    )
    decoded = tokenizer.decode(output[0])
    result = decoded[len(prefix):]
    return result.strip()

# %% [markdown]
# # ChatGPT

# %%
# Install openai 
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 KB 3.3 MB/s eta 0:00:00
# ...

# %%
# Import Library 
import openai

# %%
# Предоставляем ключ API 
openai.api_key = "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"

# %%
# Выбираем обученную модель
engine="text-davinci-003"

# %%
# Запрос 
prompt = "Что ты думаешь об интернет университете GeekBrains?" 

# Модель 
completion = openai.Completion.create(engine=engine, 
                                      prompt=prompt, 
                                      temperature=0.5, 
                                      max_tokens=1000)

# %%
# Печатаем только текст ответа
print( completion.choices[0]['text'] )
# Out:
# Я думаю, что GeekBrains является отличным ресурсом для обучения и развития технических навыков. Они предлагают обширный курс по программированию, а также много других практических курсов по различным технологиям. Кроме того, GeekBrains имеет доступную платформу для онлайн-обучения, которая помогает людям изучать новые предметы и развивать свои навыки. В общем, я считаю, что GeekBrains является отличным инструментом для обучения и развития профессиональных навыков.

# %%
# Запрос 
prompt = "Кто был президентом США в 1234 году?" 

# Модель 
completion = openai.Completion.create(engine=engine, 
                                      prompt=prompt, 
                                      temperature=0.5, 
                                      max_tokens=1000)

# %%
# Печатаем только текст ответа
print( completion.choices[0]['text'] )
# Out:
# В 1234 году президентом США не было.

# %%
# Функция для ChatGPT
def askChatGPT(prompt):
    completion = openai.Completion.create(engine="text-davinci-003", 
                                          prompt=prompt, 
                                          temperature=0.5, 
                                          max_tokens=1000)
    return completion.choices[0]['text']

# %%
askChatGPT("Земля круглая?")
# Out:
# '\n\nНет, Земля в форме эллипсоида.'

# %% [markdown]
# # Bot

# %%
# !pip install pytelegrambotapi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.9/222.9 KB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pytelegrambotapi: filename=pyTelegramBotAPI-4.10.0-py3-none-any.whl size=205420 sha256=e889794a3081ce12a8b2c2151173ae5411fc9ef97588bbb8cc65c4369612f0e3
#   Stored in directory: /root/.cache/pip/wheels/ee/e3/f1/4c142d3be2e5f09c1ba8bf5801ae61d7b2cfd9afe497872806
# Successfully built pytelegrambotapi
# ...

# %%
history_dialog = []

def babbler(text):
    global history_dialog

    history_dialog.append(text)
    history_dialog.append(respond_to_dialog(history_dialog[-10:]))
    if len(history_dialog) > 10: history_dialog = history_dialog[-10:]
    
    return history_dialog[-1]

# %% [markdown]
# Ссылка на чат-бот в телеграме: t.me/Gasilin_test_bot
#
# все api токены станут неактивными после получения оценки за этот курсовой проект. Но до этого можно поболтать с ChatGPT.

# %%
import telebot
from telebot import types

# Создаем экземпляр бота
bot = telebot.TeleBot("6103642688:AAGxMOJ9xMi8a5cNfMvEam77ZHvQd9y4HMM")

# Функция, обрабатывающая команду /start
@bot.message_handler(commands=['start'])
def start(message):
    markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
    btn1 = types.KeyboardButton("Привет")
    markup.add(btn1)
    bot.send_message(message.chat.id, "👋 Привет! Я бот- болталка! Курсовой проект Гасилина Максима.", reply_markup=markup)
    GM_Bot_Flag = 0

@bot.callback_query_handler(func=lambda call: True)
def callback_worker(call):
    global GM_Bot_Flag
    # Если нажали на одну из кнопок
    if call.data.lower() == 'медицинская болталка': 
        GM_Bot_Flag = 1
        bot.send_message(call.message.chat.id, 'О чём ты хочешь побалтать?')
    if call.data.lower() == 'chatgpt': 
        GM_Bot_Flag = 2
        bot.send_message(call.message.chat.id, 'На какой вопрос требуется дать ответ?')


# Получение сообщений от пользователя
@bot.message_handler(content_types=["text"])
def handle_text(message):
   
    global GM_Bot_Flag    
    # bot.send_message(message.chat.id, str(GM_Bot_Flag))

    if message.text.lower() == 'привет': GM_Bot_Flag = 0
    

    if GM_Bot_Flag == 0:# or message.text == 'Назад':
        # Готовим кнопки
        keyboard = types.InlineKeyboardMarkup()
        # И добавляем кнопку на экран
        key_oven = types.InlineKeyboardButton(text='Медицинская болталка', callback_data='Медицинская болталка')
        # И добавляем кнопку на экран
        keyboard.add(key_oven)
        key_telec = types.InlineKeyboardButton(text='ChatGpt', callback_data='ChatGpt')
        keyboard.add(key_telec)
        # Показываем все кнопки сразу и пишем сообщение о выборе
        bot.send_message(message.chat.id, text='Сделайте выбор', reply_markup=keyboard)
    
    elif GM_Bot_Flag == 1:
        answer = "Ответ Медицинской болталки: " + babbler(message.text)
        bot.send_message(message.chat.id, answer)
        # print(answer)
        # bot.send_message(message.chat.id, babbler(message.text))
    
    elif GM_Bot_Flag == 2:
        answer =  "Ответ ChatGPT: " + askChatGPT(message.text)
        bot.send_message(message.chat.id, answer)
        # print(answer)
 

# Запускаем бота
bot.polling(none_stop=True, interval=0)
