# %% [markdown]
# ### Задание
#
# Разобраться с моделькой перевода как она устроена
# запустить для перевода с русского на английский (при желании можно взять другие пары языков) два варианта с вниманием и без внимания
# оценить качество насколько корректно переводит (для теста отобрать примеры с увеличением длины текста) (так как оценка визуальная достаточно 20-ти примеров в тестовой выборке)

# %% [markdown]
# ### Neural machine translation

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %% [markdown]
# ### Download and prepare the dataset

# %% [markdown]
# We'll use a language dataset provided by http://www.manythings.org/anki/

# %%
# !wget -O rus-eng.zip -qq --no-check-certificate "http://www.manythings.org/anki/rus-eng.zip"
# !unzip rus-eng.zip
# Out:
# Archive:  rus-eng.zip
# replace rus.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: rus.txt
# replace _about.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: _about.txt

# %%
# Download the file
path_to_file = "rus.txt"

# %%
def preprocess_sentence(w):
    w = w.lower().strip()
    
    # creating a space between a word and the punctuation following it
    # eg: "he is a boy." => "he is a boy ."
    # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
    w = re.sub(r"([?.!,])", r" \1 ", w)
    w = re.sub(r'[" "]+', " ", w)

    # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
    w = re.sub(r"[^a-zA-Zа-яА-Я?.!,']+", " ", w)

    w = w.strip()

    # adding a start and an end token to the sentence
    # so that the model know when to start and stop predicting.
    w = '<start> ' + w + ' <end>'
    return w

# %%
preprocess_sentence("I can't go.")
# Out:
# "<start> i can't go . <end>"

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENG, RUS]
def create_dataset(path, num_examples):
    lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

    word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

    return zip(*word_pairs)

# %%
en, ru = create_dataset(path_to_file, None)
print(en[0])
print(ru[0])
# Out:
# <start> go . <end>
# <start> марш ! <end>

# %%
en[10:20]
# Out:
# ('<start> run ! <end>',
#  '<start> run . <end>',
#  '<start> run . <end>',
#  '<start> who ? <end>',
#  '<start> wow ! <end>',
#  '<start> wow ! <end>',
#  '<start> wow ! <end>',
#  '<start> wow ! <end>',
#  '<start> wow ! <end>',
#  '<start> wow ! <end>')

# %%
ru[10:20]
# Out:
# ('<start> бегите ! <end>',
#  '<start> беги ! <end>',
#  '<start> бегите ! <end>',
#  '<start> кто ? <end>',
#  '<start> вот это да ! <end>',
#  '<start> круто ! <end>',
#  '<start> здорово ! <end>',
#  '<start> ух ты ! <end>',
#  '<start> ого ! <end>',
#  '<start> вах ! <end>')

# %%
def tokenize(lang):
    lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
    lang_tokenizer.fit_on_texts(lang)

    tensor = lang_tokenizer.texts_to_sequences(lang)

    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

    return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
    # creating cleaned input, output pairs
    targ_lang, inp_lang = create_dataset(path, num_examples)

    input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
    target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

    return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
tokenize(ru[10:20])
# Out:
# (array([[ 1,  4,  3,  2,  0,  0],
#         [ 1,  5,  3,  2,  0,  0],
#         [ 1,  4,  3,  2,  0,  0],
#         [ 1,  6,  7,  2,  0,  0],
#         [ 1,  8,  9, 10,  3,  2],
#         [ 1, 11,  3,  2,  0,  0],
#         [ 1, 12,  3,  2,  0,  0],
#         [ 1, 13, 14,  3,  2,  0],
#         [ 1, 15,  3,  2,  0,  0],
#         [ 1, 16,  3,  2,  0,  0]], dtype=int32),
#  <keras.preprocessing.text.Tokenizer at 0x7f05a45500d0>)

# %% [markdown]
# ### Limit the size of the dataset to experiment faster (optional)

# %%
len(en), len(ru)
# Out:
# (451436, 451436)

# %%
# Try experimenting with the size of that dataset
num_examples = 100000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
max_length_targ, max_length_inp
# Out:
# (11, 15)

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 80000 80000 20000 20000

# %%
def convert(lang, tensor):
    for t in tensor:
        if t!=0:
            print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 4015 ----> запишите
# 8 ----> это
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 387 ----> write
# 18 ----> that
# 142 ----> down
# 3 ----> .
# 2 ----> <end>

# %% [markdown]
# ### Create a tf.data dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 300
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 15]), TensorShape([64, 11]))

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.enc_units,
                                       return_sequences=False,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
    
    
    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        return state

    
    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_hidden = encoder(example_input_batch, sample_hidden)
# print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.dec_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.fc = tf.keras.layers.Dense(vocab_size)


    
    def call(self, x, hidden):
        # enc_output shape == (batch_size, max_length, hidden_size)
        
        # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)
        
        # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
        
        # passing the concatenated vector to the GRU
        output, state = self.gru(x, initial_state=hidden)
        
        # output shape == (batch_size * 1, hidden_size)
        output = tf.reshape(output, (-1, output.shape[2]))
        
        # output shape == (batch_size, vocab)
        x = self.fc(output)
        
        return x, state

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

decoder_sample_x, decoder_sample_h = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                             sample_hidden)

# %%
decoder_sample_x.shape
# Out:
# TensorShape([64, 7335])

# %%
decoder_sample_h.shape
# Out:
# TensorShape([64, 1024])

# %% [markdown]
# ### Define the optimizer and the loss function

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %% [markdown]
# ### Checkpoints (Object-based saving)

# %%
checkpoint_dir = './training_nmt_checkpoints'

checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0

    with tf.GradientTape() as tape:
        enc_hidden = encoder(inp, enc_hidden)
        
        dec_hidden = enc_hidden
        
        dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)
        
        # Teacher forcing - feeding the target as the next input
        for t in range(1, targ.shape[1]):
            # passing enc_output to the decoder
            predictions, dec_hidden = decoder(dec_input, dec_hidden)
            
            loss += loss_function(targ[:, t], predictions)
            
            # using teacher forcing
            dec_input = tf.expand_dims(targ[:, t], 1)

    batch_loss = (loss / int(targ.shape[1]))

    variables = encoder.trainable_variables + decoder.trainable_variables

    gradients = tape.gradient(loss, variables)

    optimizer.apply_gradients(zip(gradients, variables))

    return batch_loss

# %%
# %%time

EPOCHS = 50

for epoch in range(EPOCHS):
    start = time.time()
    
    enc_hidden = encoder.initialize_hidden_state()
    total_loss = 0
    
    for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
        batch_loss = train_step(inp, targ, enc_hidden)
        total_loss += batch_loss

        if batch % 100 == 0:
            print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
    # saving (checkpoint) the model every 2 epochs
    if (epoch + 1) % 2 == 0:
        checkpoint.save(file_prefix = checkpoint_prefix)

    print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.6402
# Epoch 1 Batch 100 Loss 1.9780
# Epoch 1 Batch 200 Loss 1.8610
# Epoch 1 Batch 300 Loss 1.5728
# Epoch 1 Batch 400 Loss 1.4278
# Epoch 1 Batch 500 Loss 1.3021
# Epoch 1 Batch 600 Loss 1.3153
# Epoch 1 Batch 700 Loss 1.2174
# Epoch 1 Batch 800 Loss 1.2339
# Epoch 1 Batch 900 Loss 1.0111
# Epoch 1 Batch 1000 Loss 1.0773
# Epoch 1 Batch 1100 Loss 0.9382
# Epoch 1 Batch 1200 Loss 0.9487
# Epoch 1 Loss 1.3742
# Time taken for 1 epoch 67.24371910095215 sec
#
# Epoch 2 Batch 0 Loss 0.7849
# Epoch 2 Batch 100 Loss 0.8133
# Epoch 2 Batch 200 Loss 0.7029
# Epoch 2 Batch 300 Loss 0.7658
# Epoch 2 Batch 400 Loss 0.6218
# Epoch 2 Batch 500 Loss 0.6504
# Epoch 2 Batch 600 Loss 0.7244
# Epoch 2 Batch 700 Loss 0.5956
# Epoch 2 Batch 800 Loss 0.5975
# Epoch 2 Batch 900 Loss 0.5542
# Epoch 2 Batch 1000 Loss 0.4937
# Epoch 2 Batch 1100 Loss 0.5267
# Epoch 2 Batch 1200 Loss 0.5036
# Epoch 2 Loss 0.6508
# Time taken for 1 epoch 56.34994721412659 sec
#
# Epoch 3 Batch 0 Loss 0.2476
# Epoch 3 Batch 100 Loss 0.3017
# Epoch 3 Batch 200 Loss 0.3048
# Epoch 3 Batch 300 Loss 0.3562
# Epoch 3 Batch 400 Loss 0.3266
# Epoch 3 Batch 500 Loss 0.3617
# Epoch 3 Batch 600 Loss 0.2877
# Epoch 3 Batch 700 Loss 0.3844
# Epoch 3 Batch 800 Loss 0.2979
# Epoch 3 Batch 900 Loss 0.4305
# Epoch 3 Batch 1000 Loss 0.3646
# Epoch 3 Batch 1100 Loss 0.2850
# Epoch 3 Batch 1200 Loss 0.3656
# Epoch 3 Loss 0.3438
# Time taken for 1 epoch 55.493879079818726 sec
#
# Epoch 4 Batch 0 Loss 0.1953
# Epoch 4 Batch 100 Loss 0.1870
# Epoch 4 Batch 200 Loss 0.1927
# Epoch 4 Batch 300 Loss 0.2059
# Epoch 4 Batch 400 Loss 0.1537
# Epoch 4 Batch 500 Loss 0.1722
# Epoch 4 Batch 600 Loss 0.1877
# Epoch 4 Batch 700 Loss 0.2410
# Epoch 4 Batch 800 Loss 0.2079
# Epoch 4 Batch 900 Loss 0.2525
# Epoch 4 Batch 1000 Loss 0.1787
# Epoch 4 Batch 1100 Loss 0.2603
# Epoch 4 Batch 1200 Loss 0.2999
# Epoch 4 Loss 0.2069
# Time taken for 1 epoch 57.041967153549194 sec
#
# Epoch 5 Batch 0 Loss 0.1124
# Epoch 5 Batch 100 Loss 0.1362
# Epoch 5 Batch 200 Loss 0.1418
# Epoch 5 Batch 300 Loss 0.1642
# Epoch 5 Batch 400 Loss 0.2299
# Epoch 5 Batch 500 Loss 0.0964
# Epoch 5 Batch 600 Loss 0.1613
# Epoch 5 Batch 700 Loss 0.1561
# Epoch 5 Batch 800 Loss 0.1462
# Epoch 5 Batch 900 Loss 0.1347
# Epoch 5 Batch 1000 Loss 0.1723
# Epoch 5 Batch 1100 Loss 0.1463
# Epoch 5 Batch 1200 Loss 0.1744
# Epoch 5 Loss 0.1442
# Time taken for 1 epoch 57.84387755393982 sec
#
# Epoch 6 Batch 0 Loss 0.1080
# Epoch 6 Batch 100 Loss 0.1214
# Epoch 6 Batch 200 Loss 0.1346
# Epoch 6 Batch 300 Loss 0.1303
# Epoch 6 Batch 400 Loss 0.1113
# Epoch 6 Batch 500 Loss 0.1107
# Epoch 6 Batch 600 Loss 0.1096
# Epoch 6 Batch 700 Loss 0.1141
# Epoch 6 Batch 800 Loss 0.1300
# Epoch 6 Batch 900 Loss 0.1584
# Epoch 6 Batch 1000 Loss 0.1096
# Epoch 6 Batch 1100 Loss 0.1364
# Epoch 6 Batch 1200 Loss 0.1252
# Epoch 6 Loss 0.1144
# Time taken for 1 epoch 57.06435775756836 sec
#
# Epoch 7 Batch 0 Loss 0.1053
# Epoch 7 Batch 100 Loss 0.1171
# Epoch 7 Batch 200 Loss 0.0939
# Epoch 7 Batch 300 Loss 0.0778
# Epoch 7 Batch 400 Loss 0.0826
# Epoch 7 Batch 500 Loss 0.1026
# Epoch 7 Batch 600 Loss 0.0797
# Epoch 7 Batch 700 Loss 0.0855
# Epoch 7 Batch 800 Loss 0.0711
# Epoch 7 Batch 900 Loss 0.0995
# Epoch 7 Batch 1000 Loss 0.0991
# Epoch 7 Batch 1100 Loss 0.0667
# Epoch 7 Batch 1200 Loss 0.1206
# Epoch 7 Loss 0.0993
# Time taken for 1 epoch 56.60942316055298 sec
#
# Epoch 8 Batch 0 Loss 0.0988
# Epoch 8 Batch 100 Loss 0.0565
# Epoch 8 Batch 200 Loss 0.0727
# Epoch 8 Batch 300 Loss 0.0548
# Epoch 8 Batch 400 Loss 0.1179
# Epoch 8 Batch 500 Loss 0.0748
# Epoch 8 Batch 600 Loss 0.0816
# Epoch 8 Batch 700 Loss 0.1105
# Epoch 8 Batch 800 Loss 0.0913
# Epoch 8 Batch 900 Loss 0.1191
# Epoch 8 Batch 1000 Loss 0.0846
# Epoch 8 Batch 1100 Loss 0.1017
# Epoch 8 Batch 1200 Loss 0.0729
# Epoch 8 Loss 0.0897
# Time taken for 1 epoch 57.30898714065552 sec
#
# Epoch 9 Batch 0 Loss 0.0436
# Epoch 9 Batch 100 Loss 0.0264
# Epoch 9 Batch 200 Loss 0.0644
# Epoch 9 Batch 300 Loss 0.0917
# Epoch 9 Batch 400 Loss 0.0556
# Epoch 9 Batch 500 Loss 0.0809
# Epoch 9 Batch 600 Loss 0.0696
# Epoch 9 Batch 700 Loss 0.1014
# Epoch 9 Batch 800 Loss 0.0811
# Epoch 9 Batch 900 Loss 0.1117
# Epoch 9 Batch 1000 Loss 0.0902
# Epoch 9 Batch 1100 Loss 0.1112
# Epoch 9 Batch 1200 Loss 0.1013
# Epoch 9 Loss 0.0845
# Time taken for 1 epoch 56.735140800476074 sec
#
# Epoch 10 Batch 0 Loss 0.0712
# Epoch 10 Batch 100 Loss 0.0734
# Epoch 10 Batch 200 Loss 0.0462
# Epoch 10 Batch 300 Loss 0.0607
# Epoch 10 Batch 400 Loss 0.0819
# Epoch 10 Batch 500 Loss 0.0737
# Epoch 10 Batch 600 Loss 0.0999
# Epoch 10 Batch 700 Loss 0.0688
# Epoch 10 Batch 800 Loss 0.0802
# Epoch 10 Batch 900 Loss 0.0628
# Epoch 10 Batch 1000 Loss 0.1051
# Epoch 10 Batch 1100 Loss 0.1330
# Epoch 10 Batch 1200 Loss 0.0701
# Epoch 10 Loss 0.0813
# Time taken for 1 epoch 57.37655425071716 sec
#
# Epoch 11 Batch 0 Loss 0.0493
# Epoch 11 Batch 100 Loss 0.0785
# Epoch 11 Batch 200 Loss 0.0620
# Epoch 11 Batch 300 Loss 0.0981
# Epoch 11 Batch 400 Loss 0.0440
# Epoch 11 Batch 500 Loss 0.0688
# Epoch 11 Batch 600 Loss 0.0568
# Epoch 11 Batch 700 Loss 0.0744
# Epoch 11 Batch 800 Loss 0.1324
# Epoch 11 Batch 900 Loss 0.1060
# Epoch 11 Batch 1000 Loss 0.1226
# Epoch 11 Batch 1100 Loss 0.0566
# Epoch 11 Batch 1200 Loss 0.0994
# Epoch 11 Loss 0.0774
# Time taken for 1 epoch 56.59606981277466 sec
#
# Epoch 12 Batch 0 Loss 0.0600
# Epoch 12 Batch 100 Loss 0.0680
# Epoch 12 Batch 200 Loss 0.0461
# Epoch 12 Batch 300 Loss 0.0677
# Epoch 12 Batch 400 Loss 0.0559
# Epoch 12 Batch 500 Loss 0.0656
# Epoch 12 Batch 600 Loss 0.0942
# Epoch 12 Batch 700 Loss 0.0719
# Epoch 12 Batch 800 Loss 0.0575
# Epoch 12 Batch 900 Loss 0.0709
# Epoch 12 Batch 1000 Loss 0.0923
# Epoch 12 Batch 1100 Loss 0.1098
# Epoch 12 Batch 1200 Loss 0.1019
# Epoch 12 Loss 0.0743
# Time taken for 1 epoch 57.37682509422302 sec
#
# Epoch 13 Batch 0 Loss 0.0837
# Epoch 13 Batch 100 Loss 0.0536
# Epoch 13 Batch 200 Loss 0.0698
# Epoch 13 Batch 300 Loss 0.0613
# Epoch 13 Batch 400 Loss 0.0472
# Epoch 13 Batch 500 Loss 0.0522
# Epoch 13 Batch 600 Loss 0.0796
# Epoch 13 Batch 700 Loss 0.0943
# Epoch 13 Batch 800 Loss 0.0628
# Epoch 13 Batch 900 Loss 0.0691
# Epoch 13 Batch 1000 Loss 0.1085
# Epoch 13 Batch 1100 Loss 0.1206
# Epoch 13 Batch 1200 Loss 0.1075
# Epoch 13 Loss 0.0732
# Time taken for 1 epoch 56.50925135612488 sec
#
# Epoch 14 Batch 0 Loss 0.0493
# Epoch 14 Batch 100 Loss 0.0677
# Epoch 14 Batch 200 Loss 0.0759
# Epoch 14 Batch 300 Loss 0.0837
# Epoch 14 Batch 400 Loss 0.0846
# Epoch 14 Batch 500 Loss 0.0810
# Epoch 14 Batch 600 Loss 0.0577
# Epoch 14 Batch 700 Loss 0.0466
# Epoch 14 Batch 800 Loss 0.0682
# Epoch 14 Batch 900 Loss 0.0688
# Epoch 14 Batch 1000 Loss 0.0718
# Epoch 14 Batch 1100 Loss 0.1055
# Epoch 14 Batch 1200 Loss 0.0917
# Epoch 14 Loss 0.0716
# Time taken for 1 epoch 57.475730895996094 sec
#
# Epoch 15 Batch 0 Loss 0.0506
# Epoch 15 Batch 100 Loss 0.0478
# Epoch 15 Batch 200 Loss 0.0405
# Epoch 15 Batch 300 Loss 0.0453
# Epoch 15 Batch 400 Loss 0.0413
# Epoch 15 Batch 500 Loss 0.0655
# Epoch 15 Batch 600 Loss 0.0410
# Epoch 15 Batch 700 Loss 0.0566
# Epoch 15 Batch 800 Loss 0.0554
# Epoch 15 Batch 900 Loss 0.0307
# Epoch 15 Batch 1000 Loss 0.1164
# Epoch 15 Batch 1100 Loss 0.0586
# Epoch 15 Batch 1200 Loss 0.0735
# Epoch 15 Loss 0.0692
# Time taken for 1 epoch 56.57653784751892 sec
#
# Epoch 16 Batch 0 Loss 0.0656
# Epoch 16 Batch 100 Loss 0.0670
# Epoch 16 Batch 200 Loss 0.0741
# Epoch 16 Batch 300 Loss 0.0460
# Epoch 16 Batch 400 Loss 0.0377
# Epoch 16 Batch 500 Loss 0.0947
# Epoch 16 Batch 600 Loss 0.0513
# Epoch 16 Batch 700 Loss 0.0557
# Epoch 16 Batch 800 Loss 0.1053
# Epoch 16 Batch 900 Loss 0.1244
# Epoch 16 Batch 1000 Loss 0.0837
# Epoch 16 Batch 1100 Loss 0.1098
# Epoch 16 Batch 1200 Loss 0.1065
# Epoch 16 Loss 0.0676
# Time taken for 1 epoch 57.33572459220886 sec
#
# Epoch 17 Batch 0 Loss 0.0236
# Epoch 17 Batch 100 Loss 0.0421
# Epoch 17 Batch 200 Loss 0.0651
# Epoch 17 Batch 300 Loss 0.0250
# Epoch 17 Batch 400 Loss 0.0311
# Epoch 17 Batch 500 Loss 0.0355
# Epoch 17 Batch 600 Loss 0.0765
# Epoch 17 Batch 700 Loss 0.0871
# Epoch 17 Batch 800 Loss 0.0574
# Epoch 17 Batch 900 Loss 0.0821
# Epoch 17 Batch 1000 Loss 0.1012
# Epoch 17 Batch 1100 Loss 0.0675
# Epoch 17 Batch 1200 Loss 0.0714
# Epoch 17 Loss 0.0666
# Time taken for 1 epoch 56.712186336517334 sec
#
# Epoch 18 Batch 0 Loss 0.0463
# Epoch 18 Batch 100 Loss 0.0374
# Epoch 18 Batch 200 Loss 0.0277
# Epoch 18 Batch 300 Loss 0.0843
# Epoch 18 Batch 400 Loss 0.0871
# Epoch 18 Batch 500 Loss 0.0514
# Epoch 18 Batch 600 Loss 0.0539
# Epoch 18 Batch 700 Loss 0.0332
# Epoch 18 Batch 800 Loss 0.1301
# Epoch 18 Batch 900 Loss 0.0321
# Epoch 18 Batch 1000 Loss 0.0582
# Epoch 18 Batch 1100 Loss 0.0573
# Epoch 18 Batch 1200 Loss 0.0970
# Epoch 18 Loss 0.0656
# Time taken for 1 epoch 57.35568952560425 sec
#
# Epoch 19 Batch 0 Loss 0.0604
# Epoch 19 Batch 100 Loss 0.0407
# Epoch 19 Batch 200 Loss 0.0547
# Epoch 19 Batch 300 Loss 0.0578
# Epoch 19 Batch 400 Loss 0.0372
# Epoch 19 Batch 500 Loss 0.0384
# Epoch 19 Batch 600 Loss 0.0423
# Epoch 19 Batch 700 Loss 0.0496
# Epoch 19 Batch 800 Loss 0.1128
# Epoch 19 Batch 900 Loss 0.0692
# Epoch 19 Batch 1000 Loss 0.0894
# Epoch 19 Batch 1100 Loss 0.0758
# Epoch 19 Batch 1200 Loss 0.0800
# Epoch 19 Loss 0.0639
# Time taken for 1 epoch 56.51716208457947 sec
#
# Epoch 20 Batch 0 Loss 0.0467
# Epoch 20 Batch 100 Loss 0.0628
# Epoch 20 Batch 200 Loss 0.0633
# Epoch 20 Batch 300 Loss 0.0882
# Epoch 20 Batch 400 Loss 0.0701
# Epoch 20 Batch 500 Loss 0.0704
# Epoch 20 Batch 600 Loss 0.0370
# Epoch 20 Batch 700 Loss 0.0533
# Epoch 20 Batch 800 Loss 0.0647
# Epoch 20 Batch 900 Loss 0.0480
# Epoch 20 Batch 1000 Loss 0.0554
# Epoch 20 Batch 1100 Loss 0.0488
# Epoch 20 Batch 1200 Loss 0.0440
# Epoch 20 Loss 0.0625
# Time taken for 1 epoch 57.26498603820801 sec
#
# Epoch 21 Batch 0 Loss 0.0583
# Epoch 21 Batch 100 Loss 0.0648
# Epoch 21 Batch 200 Loss 0.0586
# Epoch 21 Batch 300 Loss 0.0463
# Epoch 21 Batch 400 Loss 0.0326
# Epoch 21 Batch 500 Loss 0.0409
# Epoch 21 Batch 600 Loss 0.0833
# Epoch 21 Batch 700 Loss 0.0644
# Epoch 21 Batch 800 Loss 0.0420
# Epoch 21 Batch 900 Loss 0.0573
# Epoch 21 Batch 1000 Loss 0.1078
# Epoch 21 Batch 1100 Loss 0.0608
# Epoch 21 Batch 1200 Loss 0.0716
# Epoch 21 Loss 0.0625
# Time taken for 1 epoch 56.637173891067505 sec
#
# Epoch 22 Batch 0 Loss 0.0559
# Epoch 22 Batch 100 Loss 0.0444
# Epoch 22 Batch 200 Loss 0.0346
# Epoch 22 Batch 300 Loss 0.0662
# Epoch 22 Batch 400 Loss 0.0539
# Epoch 22 Batch 500 Loss 0.0482
# Epoch 22 Batch 600 Loss 0.0648
# Epoch 22 Batch 700 Loss 0.0665
# Epoch 22 Batch 800 Loss 0.0707
# Epoch 22 Batch 900 Loss 0.0669
# Epoch 22 Batch 1000 Loss 0.0452
# Epoch 22 Batch 1100 Loss 0.0513
# Epoch 22 Batch 1200 Loss 0.0708
# Epoch 22 Loss 0.0611
# Time taken for 1 epoch 57.47133255004883 sec
#
# Epoch 23 Batch 0 Loss 0.0382
# Epoch 23 Batch 100 Loss 0.0537
# Epoch 23 Batch 200 Loss 0.0375
# Epoch 23 Batch 300 Loss 0.0752
# Epoch 23 Batch 400 Loss 0.0487
# Epoch 23 Batch 500 Loss 0.0485
# Epoch 23 Batch 600 Loss 0.0635
# Epoch 23 Batch 700 Loss 0.0541
# Epoch 23 Batch 800 Loss 0.0411
# Epoch 23 Batch 900 Loss 0.0617
# Epoch 23 Batch 1000 Loss 0.0444
# Epoch 23 Batch 1100 Loss 0.0703
# Epoch 23 Batch 1200 Loss 0.0643
# Epoch 23 Loss 0.0612
# Time taken for 1 epoch 56.63860058784485 sec
#
# Epoch 24 Batch 0 Loss 0.0756
# Epoch 24 Batch 100 Loss 0.0322
# Epoch 24 Batch 200 Loss 0.0723
# Epoch 24 Batch 300 Loss 0.0671
# Epoch 24 Batch 400 Loss 0.0429
# Epoch 24 Batch 500 Loss 0.1107
# Epoch 24 Batch 600 Loss 0.0482
# Epoch 24 Batch 700 Loss 0.0354
# Epoch 24 Batch 800 Loss 0.0676
# Epoch 24 Batch 900 Loss 0.1031
# Epoch 24 Batch 1000 Loss 0.0613
# Epoch 24 Batch 1100 Loss 0.0378
# Epoch 24 Batch 1200 Loss 0.0966
# Epoch 24 Loss 0.0594
# Time taken for 1 epoch 57.162984132766724 sec
#
# Epoch 25 Batch 0 Loss 0.0770
# Epoch 25 Batch 100 Loss 0.0307
# Epoch 25 Batch 200 Loss 0.0362
# Epoch 25 Batch 300 Loss 0.0892
# Epoch 25 Batch 400 Loss 0.0442
# Epoch 25 Batch 500 Loss 0.0377
# Epoch 25 Batch 600 Loss 0.0814
# Epoch 25 Batch 700 Loss 0.0419
# Epoch 25 Batch 800 Loss 0.0783
# Epoch 25 Batch 900 Loss 0.0422
# Epoch 25 Batch 1000 Loss 0.0510
# Epoch 25 Batch 1100 Loss 0.0762
# Epoch 25 Batch 1200 Loss 0.0768
# Epoch 25 Loss 0.0584
# Time taken for 1 epoch 56.71612477302551 sec
#
# Epoch 26 Batch 0 Loss 0.0284
# Epoch 26 Batch 100 Loss 0.0447
# Epoch 26 Batch 200 Loss 0.0364
# Epoch 26 Batch 300 Loss 0.0172
# Epoch 26 Batch 400 Loss 0.0509
# Epoch 26 Batch 500 Loss 0.0233
# Epoch 26 Batch 600 Loss 0.0282
# Epoch 26 Batch 700 Loss 0.0357
# Epoch 26 Batch 800 Loss 0.0625
# Epoch 26 Batch 900 Loss 0.0749
# Epoch 26 Batch 1000 Loss 0.0903
# Epoch 26 Batch 1100 Loss 0.0796
# Epoch 26 Batch 1200 Loss 0.0566
# Epoch 26 Loss 0.0574
# Time taken for 1 epoch 57.20080089569092 sec
#
# Epoch 27 Batch 0 Loss 0.0297
# Epoch 27 Batch 100 Loss 0.0600
# Epoch 27 Batch 200 Loss 0.0404
# Epoch 27 Batch 300 Loss 0.0412
# Epoch 27 Batch 400 Loss 0.0339
# Epoch 27 Batch 500 Loss 0.0875
# Epoch 27 Batch 600 Loss 0.0486
# Epoch 27 Batch 700 Loss 0.0378
# Epoch 27 Batch 800 Loss 0.0950
# Epoch 27 Batch 900 Loss 0.0575
# Epoch 27 Batch 1000 Loss 0.0496
# Epoch 27 Batch 1100 Loss 0.0559
# Epoch 27 Batch 1200 Loss 0.0427
# Epoch 27 Loss 0.0573
# Time taken for 1 epoch 56.47670578956604 sec
#
# Epoch 28 Batch 0 Loss 0.0592
# Epoch 28 Batch 100 Loss 0.0417
# Epoch 28 Batch 200 Loss 0.0542
# Epoch 28 Batch 300 Loss 0.0722
# Epoch 28 Batch 400 Loss 0.0558
# Epoch 28 Batch 500 Loss 0.0648
# Epoch 28 Batch 600 Loss 0.0714
# Epoch 28 Batch 700 Loss 0.0452
# Epoch 28 Batch 800 Loss 0.0518
# Epoch 28 Batch 900 Loss 0.0534
# Epoch 28 Batch 1000 Loss 0.0696
# Epoch 28 Batch 1100 Loss 0.0317
# Epoch 28 Batch 1200 Loss 0.0436
# Epoch 28 Loss 0.0571
# Time taken for 1 epoch 57.25618124008179 sec
#
# Epoch 29 Batch 0 Loss 0.0491
# Epoch 29 Batch 100 Loss 0.0449
# Epoch 29 Batch 200 Loss 0.0606
# Epoch 29 Batch 300 Loss 0.0227
# Epoch 29 Batch 400 Loss 0.0740
# Epoch 29 Batch 500 Loss 0.0417
# Epoch 29 Batch 600 Loss 0.0638
# Epoch 29 Batch 700 Loss 0.0387
# Epoch 29 Batch 800 Loss 0.0432
# Epoch 29 Batch 900 Loss 0.0685
# Epoch 29 Batch 1000 Loss 0.0834
# Epoch 29 Batch 1100 Loss 0.0507
# Epoch 29 Batch 1200 Loss 0.0696
# Epoch 29 Loss 0.0560
# Time taken for 1 epoch 56.50771403312683 sec
#
# Epoch 30 Batch 0 Loss 0.0552
# Epoch 30 Batch 100 Loss 0.0316
# Epoch 30 Batch 200 Loss 0.0558
# Epoch 30 Batch 300 Loss 0.0216
# Epoch 30 Batch 400 Loss 0.0445
# Epoch 30 Batch 500 Loss 0.0515
# Epoch 30 Batch 600 Loss 0.0822
# Epoch 30 Batch 700 Loss 0.0449
# Epoch 30 Batch 800 Loss 0.0612
# Epoch 30 Batch 900 Loss 0.0931
# Epoch 30 Batch 1000 Loss 0.0541
# Epoch 30 Batch 1100 Loss 0.0852
# Epoch 30 Batch 1200 Loss 0.0830
# Epoch 30 Loss 0.0554
# Time taken for 1 epoch 57.25308036804199 sec
#
# Epoch 31 Batch 0 Loss 0.0505
# Epoch 31 Batch 100 Loss 0.0296
# Epoch 31 Batch 200 Loss 0.0287
# Epoch 31 Batch 300 Loss 0.0331
# Epoch 31 Batch 400 Loss 0.0385
# Epoch 31 Batch 500 Loss 0.0284
# Epoch 31 Batch 600 Loss 0.0563
# Epoch 31 Batch 700 Loss 0.0528
# Epoch 31 Batch 800 Loss 0.0852
# Epoch 31 Batch 900 Loss 0.0581
# Epoch 31 Batch 1000 Loss 0.0538
# Epoch 31 Batch 1100 Loss 0.1032
# Epoch 31 Batch 1200 Loss 0.0668
# Epoch 31 Loss 0.0542
# Time taken for 1 epoch 56.53710627555847 sec
#
# Epoch 32 Batch 0 Loss 0.0372
# Epoch 32 Batch 100 Loss 0.0421
# Epoch 32 Batch 200 Loss 0.0539
# Epoch 32 Batch 300 Loss 0.0654
# Epoch 32 Batch 400 Loss 0.0299
# Epoch 32 Batch 500 Loss 0.0568
# Epoch 32 Batch 600 Loss 0.0780
# Epoch 32 Batch 700 Loss 0.0740
# Epoch 32 Batch 800 Loss 0.0513
# Epoch 32 Batch 900 Loss 0.0444
# Epoch 32 Batch 1000 Loss 0.0499
# Epoch 32 Batch 1100 Loss 0.0471
# Epoch 32 Batch 1200 Loss 0.0383
# Epoch 32 Loss 0.0543
# Time taken for 1 epoch 57.26279377937317 sec
#
# Epoch 33 Batch 0 Loss 0.0818
# Epoch 33 Batch 100 Loss 0.0600
# Epoch 33 Batch 200 Loss 0.0386
# Epoch 33 Batch 300 Loss 0.0444
# Epoch 33 Batch 400 Loss 0.0695
# Epoch 33 Batch 500 Loss 0.0591
# Epoch 33 Batch 600 Loss 0.0508
# Epoch 33 Batch 700 Loss 0.0775
# Epoch 33 Batch 800 Loss 0.0285
# Epoch 33 Batch 900 Loss 0.0361
# Epoch 33 Batch 1000 Loss 0.0643
# Epoch 33 Batch 1100 Loss 0.0436
# Epoch 33 Batch 1200 Loss 0.0457
# Epoch 33 Loss 0.0531
# Time taken for 1 epoch 56.60597014427185 sec
#
# Epoch 34 Batch 0 Loss 0.0332
# Epoch 34 Batch 100 Loss 0.0285
# Epoch 34 Batch 200 Loss 0.0581
# Epoch 34 Batch 300 Loss 0.0615
# Epoch 34 Batch 400 Loss 0.0199
# Epoch 34 Batch 500 Loss 0.0603
# Epoch 34 Batch 600 Loss 0.0621
# Epoch 34 Batch 700 Loss 0.0212
# Epoch 34 Batch 800 Loss 0.0452
# Epoch 34 Batch 900 Loss 0.0520
# Epoch 34 Batch 1000 Loss 0.0717
# Epoch 34 Batch 1100 Loss 0.0556
# Epoch 34 Batch 1200 Loss 0.0398
# Epoch 34 Loss 0.0529
# Time taken for 1 epoch 57.47509741783142 sec
#
# Epoch 35 Batch 0 Loss 0.0516
# Epoch 35 Batch 100 Loss 0.0343
# Epoch 35 Batch 200 Loss 0.0344
# Epoch 35 Batch 300 Loss 0.0590
# Epoch 35 Batch 400 Loss 0.0408
# Epoch 35 Batch 500 Loss 0.0238
# Epoch 35 Batch 600 Loss 0.0377
# Epoch 35 Batch 700 Loss 0.0668
# Epoch 35 Batch 800 Loss 0.0621
# Epoch 35 Batch 900 Loss 0.0712
# Epoch 35 Batch 1000 Loss 0.0324
# Epoch 35 Batch 1100 Loss 0.0461
# Epoch 35 Batch 1200 Loss 0.0592
# Epoch 35 Loss 0.0522
# Time taken for 1 epoch 56.65237259864807 sec
#
# Epoch 36 Batch 0 Loss 0.0620
# Epoch 36 Batch 100 Loss 0.0201
# Epoch 36 Batch 200 Loss 0.0259
# Epoch 36 Batch 300 Loss 0.0290
# Epoch 36 Batch 400 Loss 0.0432
# Epoch 36 Batch 500 Loss 0.0290
# Epoch 36 Batch 600 Loss 0.0650
# Epoch 36 Batch 700 Loss 0.0629
# Epoch 36 Batch 800 Loss 0.0650
# Epoch 36 Batch 900 Loss 0.1098
# Epoch 36 Batch 1000 Loss 0.0606
# Epoch 36 Batch 1100 Loss 0.0493
# Epoch 36 Batch 1200 Loss 0.0644
# Epoch 36 Loss 0.0513
# Time taken for 1 epoch 57.307610750198364 sec
#
# Epoch 37 Batch 0 Loss 0.0622
# Epoch 37 Batch 100 Loss 0.0393
# Epoch 37 Batch 200 Loss 0.0544
# Epoch 37 Batch 300 Loss 0.0556
# Epoch 37 Batch 400 Loss 0.0536
# Epoch 37 Batch 500 Loss 0.0701
# Epoch 37 Batch 600 Loss 0.0524
# Epoch 37 Batch 700 Loss 0.0339
# Epoch 37 Batch 800 Loss 0.0513
# Epoch 37 Batch 900 Loss 0.0682
# Epoch 37 Batch 1000 Loss 0.0438
# Epoch 37 Batch 1100 Loss 0.0585
# Epoch 37 Batch 1200 Loss 0.0351
# Epoch 37 Loss 0.0520
# Time taken for 1 epoch 56.752137422561646 sec
#
# Epoch 38 Batch 0 Loss 0.0303
# Epoch 38 Batch 100 Loss 0.0308
# Epoch 38 Batch 200 Loss 0.0372
# Epoch 38 Batch 300 Loss 0.0414
# Epoch 38 Batch 400 Loss 0.0590
# Epoch 38 Batch 500 Loss 0.0683
# Epoch 38 Batch 600 Loss 0.0313
# Epoch 38 Batch 700 Loss 0.0529
# Epoch 38 Batch 800 Loss 0.0549
# Epoch 38 Batch 900 Loss 0.0465
# Epoch 38 Batch 1000 Loss 0.0233
# Epoch 38 Batch 1100 Loss 0.0853
# Epoch 38 Batch 1200 Loss 0.0689
# Epoch 38 Loss 0.0509
# Time taken for 1 epoch 57.639485359191895 sec
#
# Epoch 39 Batch 0 Loss 0.0433
# Epoch 39 Batch 100 Loss 0.0485
# Epoch 39 Batch 200 Loss 0.0384
# Epoch 39 Batch 300 Loss 0.0728
# Epoch 39 Batch 400 Loss 0.0299
# Epoch 39 Batch 500 Loss 0.0345
# Epoch 39 Batch 600 Loss 0.0599
# Epoch 39 Batch 700 Loss 0.0548
# Epoch 39 Batch 800 Loss 0.0560
# Epoch 39 Batch 900 Loss 0.0453
# Epoch 39 Batch 1000 Loss 0.0568
# Epoch 39 Batch 1100 Loss 0.0487
# Epoch 39 Batch 1200 Loss 0.0657
# Epoch 39 Loss 0.0503
# Time taken for 1 epoch 56.81816840171814 sec
#
# Epoch 40 Batch 0 Loss 0.0389
# Epoch 40 Batch 100 Loss 0.0286
# Epoch 40 Batch 200 Loss 0.0756
# Epoch 40 Batch 300 Loss 0.0750
# Epoch 40 Batch 400 Loss 0.0414
# Epoch 40 Batch 500 Loss 0.0469
# Epoch 40 Batch 600 Loss 0.0415
# Epoch 40 Batch 700 Loss 0.0620
# Epoch 40 Batch 800 Loss 0.0371
# Epoch 40 Batch 900 Loss 0.0634
# Epoch 40 Batch 1000 Loss 0.0400
# Epoch 40 Batch 1100 Loss 0.0364
# Epoch 40 Batch 1200 Loss 0.0559
# Epoch 40 Loss 0.0500
# Time taken for 1 epoch 57.50279712677002 sec
#
# Epoch 41 Batch 0 Loss 0.0334
# Epoch 41 Batch 100 Loss 0.0331
# Epoch 41 Batch 200 Loss 0.0433
# Epoch 41 Batch 300 Loss 0.0441
# Epoch 41 Batch 400 Loss 0.0383
# Epoch 41 Batch 500 Loss 0.0570
# Epoch 41 Batch 600 Loss 0.0585
# Epoch 41 Batch 700 Loss 0.0560
# Epoch 41 Batch 800 Loss 0.0851
# Epoch 41 Batch 900 Loss 0.0580
# Epoch 41 Batch 1000 Loss 0.0358
# Epoch 41 Batch 1100 Loss 0.0339
# Epoch 41 Batch 1200 Loss 0.0393
# Epoch 41 Loss 0.0496
# Time taken for 1 epoch 56.88226771354675 sec
#
# Epoch 42 Batch 0 Loss 0.0417
# Epoch 42 Batch 100 Loss 0.0355
# Epoch 42 Batch 200 Loss 0.0811
# Epoch 42 Batch 300 Loss 0.0389
# Epoch 42 Batch 400 Loss 0.0672
# Epoch 42 Batch 500 Loss 0.0711
# Epoch 42 Batch 600 Loss 0.0420
# Epoch 42 Batch 700 Loss 0.0452
# Epoch 42 Batch 800 Loss 0.0401
# Epoch 42 Batch 900 Loss 0.0359
# Epoch 42 Batch 1000 Loss 0.0377
# Epoch 42 Batch 1100 Loss 0.0791
# Epoch 42 Batch 1200 Loss 0.0352
# Epoch 42 Loss 0.0489
# Time taken for 1 epoch 57.50363206863403 sec
#
# Epoch 43 Batch 0 Loss 0.0534
# Epoch 43 Batch 100 Loss 0.0309
# Epoch 43 Batch 200 Loss 0.0283
# Epoch 43 Batch 300 Loss 0.0535
# Epoch 43 Batch 400 Loss 0.0198
# Epoch 43 Batch 500 Loss 0.0655
# Epoch 43 Batch 600 Loss 0.0320
# Epoch 43 Batch 700 Loss 0.0503
# Epoch 43 Batch 800 Loss 0.0752
# Epoch 43 Batch 900 Loss 0.0320
# Epoch 43 Batch 1000 Loss 0.0436
# Epoch 43 Batch 1100 Loss 0.0507
# Epoch 43 Batch 1200 Loss 0.0745
# Epoch 43 Loss 0.0492
# Time taken for 1 epoch 56.56326603889465 sec
#
# Epoch 44 Batch 0 Loss 0.0300
# Epoch 44 Batch 100 Loss 0.0501
# Epoch 44 Batch 200 Loss 0.0460
# Epoch 44 Batch 300 Loss 0.0370
# Epoch 44 Batch 400 Loss 0.0825
# Epoch 44 Batch 500 Loss 0.0638
# Epoch 44 Batch 600 Loss 0.0636
# Epoch 44 Batch 700 Loss 0.0819
# Epoch 44 Batch 800 Loss 0.0407
# Epoch 44 Batch 900 Loss 0.0432
# Epoch 44 Batch 1000 Loss 0.0533
# Epoch 44 Batch 1100 Loss 0.0593
# Epoch 44 Batch 1200 Loss 0.0537
# Epoch 44 Loss 0.0485
# Time taken for 1 epoch 57.45567464828491 sec
#
# Epoch 45 Batch 0 Loss 0.0422
# Epoch 45 Batch 100 Loss 0.0637
# Epoch 45 Batch 200 Loss 0.0269
# Epoch 45 Batch 300 Loss 0.0462
# Epoch 45 Batch 400 Loss 0.0213
# Epoch 45 Batch 500 Loss 0.0328
# Epoch 45 Batch 600 Loss 0.0629
# Epoch 45 Batch 700 Loss 0.0518
# Epoch 45 Batch 800 Loss 0.0442
# Epoch 45 Batch 900 Loss 0.0688
# Epoch 45 Batch 1000 Loss 0.0525
# Epoch 45 Batch 1100 Loss 0.0444
# Epoch 45 Batch 1200 Loss 0.0578
# Epoch 45 Loss 0.0483
# Time taken for 1 epoch 56.58140826225281 sec
#
# Epoch 46 Batch 0 Loss 0.0365
# Epoch 46 Batch 100 Loss 0.0400
# Epoch 46 Batch 200 Loss 0.0291
# Epoch 46 Batch 300 Loss 0.0536
# Epoch 46 Batch 400 Loss 0.0371
# Epoch 46 Batch 500 Loss 0.0239
# Epoch 46 Batch 600 Loss 0.0584
# Epoch 46 Batch 700 Loss 0.0446
# Epoch 46 Batch 800 Loss 0.0583
# Epoch 46 Batch 900 Loss 0.0264
# Epoch 46 Batch 1000 Loss 0.0629
# Epoch 46 Batch 1100 Loss 0.0658
# Epoch 46 Batch 1200 Loss 0.0602
# Epoch 46 Loss 0.0477
# Time taken for 1 epoch 57.36711502075195 sec
#
# Epoch 47 Batch 0 Loss 0.0434
# Epoch 47 Batch 100 Loss 0.0323
# Epoch 47 Batch 200 Loss 0.0240
# Epoch 47 Batch 300 Loss 0.0407
# Epoch 47 Batch 400 Loss 0.0476
# Epoch 47 Batch 500 Loss 0.0366
# Epoch 47 Batch 600 Loss 0.0439
# Epoch 47 Batch 700 Loss 0.0261
# Epoch 47 Batch 800 Loss 0.0791
# Epoch 47 Batch 900 Loss 0.0581
# Epoch 47 Batch 1000 Loss 0.0381
# Epoch 47 Batch 1100 Loss 0.0358
# Epoch 47 Batch 1200 Loss 0.0650
# Epoch 47 Loss 0.0480
# Time taken for 1 epoch 56.682944774627686 sec
#
# Epoch 48 Batch 0 Loss 0.0360
# Epoch 48 Batch 100 Loss 0.0070
# Epoch 48 Batch 200 Loss 0.0172
# Epoch 48 Batch 300 Loss 0.0317
# Epoch 48 Batch 400 Loss 0.0303
# Epoch 48 Batch 500 Loss 0.0253
# Epoch 48 Batch 600 Loss 0.0605
# Epoch 48 Batch 700 Loss 0.0516
# Epoch 48 Batch 800 Loss 0.0548
# Epoch 48 Batch 900 Loss 0.0373
# Epoch 48 Batch 1000 Loss 0.0637
# Epoch 48 Batch 1100 Loss 0.0462
# Epoch 48 Batch 1200 Loss 0.0594
# Epoch 48 Loss 0.0472
# Time taken for 1 epoch 57.38118934631348 sec
#
# Epoch 49 Batch 0 Loss 0.0399
# Epoch 49 Batch 100 Loss 0.0353
# Epoch 49 Batch 200 Loss 0.0372
# Epoch 49 Batch 300 Loss 0.0509
# Epoch 49 Batch 400 Loss 0.0390
# Epoch 49 Batch 500 Loss 0.0644
# Epoch 49 Batch 600 Loss 0.0232
# Epoch 49 Batch 700 Loss 0.0403
# Epoch 49 Batch 800 Loss 0.0545
# Epoch 49 Batch 900 Loss 0.0335
# Epoch 49 Batch 1000 Loss 0.0810
# Epoch 49 Batch 1100 Loss 0.0628
# Epoch 49 Batch 1200 Loss 0.0649
# Epoch 49 Loss 0.0474
# Time taken for 1 epoch 56.74330925941467 sec
#
# Epoch 50 Batch 0 Loss 0.0210
# Epoch 50 Batch 100 Loss 0.0278
# Epoch 50 Batch 200 Loss 0.0431
# Epoch 50 Batch 300 Loss 0.0482
# Epoch 50 Batch 400 Loss 0.0311
# Epoch 50 Batch 500 Loss 0.0632
# Epoch 50 Batch 600 Loss 0.0416
# Epoch 50 Batch 700 Loss 0.0469
# Epoch 50 Batch 800 Loss 0.0797
# Epoch 50 Batch 900 Loss 0.0701
# Epoch 50 Batch 1000 Loss 0.0465
# Epoch 50 Batch 1100 Loss 0.0454
# Epoch 50 Batch 1200 Loss 0.0732
# Epoch 50 Loss 0.0466
# Time taken for 1 epoch 57.196916341781616 sec
#
# CPU times: user 33min 56s, sys: 3min 3s, total: 36min 59s
# Wall time: 47min 39s

# %% [markdown]
# ### Translate

# %% [markdown]
# - The evaluate function is similar to the training loop, except we don't use teacher forcing here. The input to the decoder at each time step is its previous predictions along with the hidden state and the encoder output.
# - Stop predicting when the model predicts the end token.
# - And store the attention weights for every time step.
# Note: The encoder output is calculated only once for one input.

# %%
def evaluate(sentence):
    attention_plot = np.zeros((max_length_targ, max_length_inp))

    sentence = preprocess_sentence(sentence)

    inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
    inputs = tf.convert_to_tensor(inputs)

    result = ''

    hidden = [tf.zeros((1, units))]
    enc_hidden = encoder(inputs, hidden)

    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

    for t in range(max_length_targ):
        predictions, dec_hidden = decoder(dec_input, dec_hidden)
        
        # storing the attention weights to plot later on
        predicted_id = tf.argmax(predictions[0]).numpy()
        result += targ_lang.index_word[predicted_id] + ' '
        
        if targ_lang.index_word[predicted_id] == '<end>':
            return result, sentence

        # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)

    return result, sentence

# %%
def translate(sentence):
    result, sentence = evaluate(sentence)
    
    print('Input: %s' % (sentence))
    print('Predicted translation: {}'.format(result))

# %% [markdown]
# ### Restore the latest checkpoint and test

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate('Здесь хорошо.')
# Out:
# Input: <start> здесь хорошо . <end>
# Predicted translation: it's good here . <end>

# %%
translate('Я делаю работу')
# Out:
# Input: <start> я делаю работу <end>
# Predicted translation: am i doing the job ? <end>

# %%
translate('Он смотрит в ')
# Out:
# Input: <start> он смотрит в <end>
# Predicted translation: he's looking at her . <end>

# %%
translate('Она пошла в магазин')
# Out:
# Input: <start> она пошла в магазин <end>
# Predicted translation: she went to the shop ? <end>

# %%
translate('Получилось неплохо')
# Out:
# Input: <start> получилось неплохо <end>
# Predicted translation: mary shaves her well . <end>

# %%
translate('Я молодец')
# Out:
# Input: <start> я молодец <end>
# Predicted translation: i'm a bit fat . <end>
