# %% [markdown]
# ## 1 Задание.
# Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.

# %%
a = 200
b = 800

# %%
Mx = (a+b)/2
Mx
# Out:
# 500.0

# %%
Dx = ((b-a)**2) / 12
Dx
# Out:
# 30000.0

# %% [markdown]
# #### Среднее = 500
# #### Дисперсия = 30000

# %% [markdown]
# ## 2 Задание.
# О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# Если да, найдите ее.

# %%
Dx = 0.2
a = 0.5

# %% [markdown]
# Выразим b из формулы дисперсии. Только при извлечении квадратного корня мы можем получить как положительное, так и отрицательное число. Но отрицательное не стоит рассмтривать, т.к. правая граница не может быть меньше левой.

# %%
b = (12*Dx)**0.5 + a
print(b)
b_bad = -(12*Dx)**0.5 + a
print(b_bad)
# Out:
# 2.049193338482967
# -1.0491933384829668

# %%
Mx = (a+b) / 2
Mx
# Out:
# 1.2745966692414834

# %% [markdown]
# #### Правая граница = 2.049193338482967
# #### Среднее = 1.2745966692414834

# %% [markdown]
# ## 3 Задание.
# Непрерывная случайная величина X распределена нормально и задана плотностью распределения
# $f(x) = \frac{1}{4 * \sqrt{2*pi}} * e^{\frac{-(x+2)^2}{32}}$.
# Найдите:
# а). M(X)
# б). D(X)
# в). std(X) (среднее квадратичное отклонение)

# %% [markdown]
# $$f(x) = \frac{1}{4 * \sqrt{2*pi}} * e^{\frac{-(x+2)^2}{32}} = \frac{1}{4 * \sqrt{2*pi}} * e^{-\frac{1}{2}(\frac{x+2}{4})^2} = \frac{1}{\sigma * \sqrt{2*pi}} * e^{-\frac{1}{2}(\frac{x-\mu}{\sigma})^2} $$

# %% [markdown]
# #### Среднее = $\mu$ = -2
# #### Стандартное отклонение = $\sigma$ = 4
# #### Дисперсия = $\sigma^2$ =  16

# %% [markdown]
# ## 4 Задание.

# %% [markdown]
# 4. Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
#
# а). больше 182 см
#
# б). больше 190 см
#
# в). от 166 см до 190 см
#
# г). от 166 см до 182 см
#
# д). от 158 см до 190 см
#
# е). не выше 150 см или не ниже 190 см
#
# ё). не выше 150 см или не ниже 198 см
#
# ж). ниже 166 см.

# %%
std = 8
Mx = 174

# %%
Z1 = (182 - Mx) / std
Z1
# Out:
# 1.0

# %%
P = 1 - 0.8413 #т.к считаем "Больше", то отнимаем от 1
P
# Out:
# 0.15869999999999995

# %% [markdown]
# При Z = 1, P = 0.1586

# %%
Z2 = (190 - Mx) / std
Z2
# Out:
# 2.0

# %%
P2 = 1 - 0.9772 #т.к считаем "Больше", то отнимаем от 1
P2
# Out:
# 0.022800000000000042

# %%
Z31 = (166 - Mx) / std
Z31 #P = 0.1587
# Out:
# -1.0

# %%
Z32 = (190 - Mx) / std
Z32 # P = 0.9772
# Out:
# 2.0

# %%
P3 =  0.9772 - 0.1587 # Получаем промежуток вероятности между 2 вероятностями
P3
# Out:
# 0.8185

# %%
P4 = 0.8413 - 0.1587 # Получаем промежуток вероятности между 2 вероятностями
P4
# Out:
# 0.6826000000000001

# %%
Z51 = (158 - Mx) / std
Z51 # P = 0.0228
# Out:
# -2.0

# %%
P5 = 0.9772 - 0.0228 # Получаем промежуток вероятности между 2 вероятностями
P5
# Out:
# 0.9543999999999999

# %%
Z61 = (150 - Mx) / std
Z61 # P = 0.00135
# Out:
# -3.0

# %%
P6 = 0.00135 + (1-0.9772)
P6
# Out:
# 0.024150000000000043

# %%
Z72 = (198 - Mx) / std
Z72 # P = 0.99865
# Out:
# 3.0

# %%
P7 = 0.00135 + (1-0.99865)
P7
# Out:
# 0.0026999999999999624

# %%
Z8 = (166 - Mx) / std
Z8
# Out:
# -1.0

# %% [markdown]
# P8 = 0.1587

# %% [markdown]
# #### Ответы:
# - а) Р = 0.1587
# - б) Р = 0.0228
# - в) Р = 0.8185
# - г) Р = 0.6826
# - д) Р = 0.9544
# - е) Р = 0.02415
# - ё) Р = 0.0027
# - ж) Р = 0.1587

# %% [markdown]
# ## 5 Задание
# На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %%
x = 190
std = 5
Mx = 178

# %%
Z = (x-Mx) / std
Z
# Out:
# 2.4

# %% [markdown]
# ### Ответ: на 2.4 сигмы
